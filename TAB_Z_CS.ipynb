# %% [markdown]
# <body>
#     <div>
#         <center>
#             <br>
#             <h1><b>Detection of Opinion Spam or false opinion</b></h1>
#             <br>
#             <h3><b>07.12.2020</b></h3>
#             <br>
#             <h2><b>TAB_Z_CS</b></h2>
#             <br>
#             <h4><b>Akram Ourir</b></h4>
#             <h4><b>Ankesh Anupam</b></h4>
#             <h4><b>Tsegazab Tesfay</b></h4>
#             <h4><b>Rauan Zhamangarin</b></h4>
#             <h4><b>Sham Yohannes Beemnet</b></h4>
#             <h4><b>Christoffer Andersen Gabrielsen</b></h4>
#             <br>
#         </center>
#     </div>
# </body>

# %% [markdown]
# ## Contributions:
# Akram : Data cleaning and exploration (coding of: duplicate lines detection and removal, stemming function, stop word list analysis and update, hotelname as single feature), multiple models in traditional approaches for both tfdif & countvectorizer, calculate scores, comparing the different models F1score, accuaracy & auc, plotting the different scores, gidsearch and optimization...), commenting the classical approach and the results, report structure, Abstract, conclusion, introduction. Coordination with team.
#
# Ankesh: n-gram function, coding neural network approach with word embedding,trying different Neural Network Approaches with Glove. Did literature review and organized team meetings and coordinating. Commenting the code.
#
# Rauan: Implementation of Random forest code, Coding neural network approach with word embedding, trying different Neural Network Approaches with Glove. Commenting the code.
#
# Tsegazab : With previous experience in ML explained concept to other team members in the start, (coding of: data exploration and cleaning,reviewwithouthotelname function, removing stop words, coding of the classifier class, svm, decision tree and logistic regression, countvectorizer features, tfidf features, gidsearch and optimization, coding and commenting of the approach neural network using tfidf with MLP and its results.
#
# Sham: Data cleaning and exploration (dictionary for stop words), coding some of classical approach naive bayes, commenting, updating codes for better visualization, introduction, conclusion and abstracts,
#
# Christoffer: Fine tuning and helping with multiple codes and functions for reading and cleaning data, data exploration and visualization, commenting , Google colab compability, coding neural network using word2vec.
#
# All the team worked togetether through bidaily meetings for two weeks where all the team contributed to the understanding of the concept and how we code through also sharing knowledge and literature data. Most of us have no big previous experience. Tzegazab was a big help specially in the beginning with his experience to get us starting. At the end all the team knowledge had much improved, while still some black boxes in the neural network part, we think that we will have the opportunity through the master to get more understanding and experience.

# %% [markdown]
# ## Abstract

# %% [markdown]
# In this project, we are using NLP techniques in a supervised approach to classify 1600 reviews from different hotels in Chicago from different sources to truthful and deceptful.
# Different machine leaning approaches were used in classical approach (svm, decision tree, random forest, logistic regression, naive Bayes, K neighbors and stochastic gradient descent for sklearn library) and neural network approach. These different approaches needed different cleaning and features engineering. For the classical approach, we used bag of word (BoW) technique which consists in using a word or a sequence of words (ngrams).
#
# In the classical approaches, after cleaning the data, removing duplicate reviews, the frequency or the count of the ngrams (onegram and bigram) are the features used. Specially, two features engineering technique were used from sklearn library. First, countvectoriser, which simply transform the review to a vector representing the number of times the ngrams appears in the review. For the counverctoriser features we needed to clean the data by removing stop words, stemming, and grouping hotel names to a single word. Second, Tf-idf, which instead of using the number of times, it uses number of times the ngram appears in a review multiplied by the inverse frequency of the word across the whole set of review. Thus, Tf-idf methods do not need a lot of cleaning of the data as the stop words will have automatically lower importance. So, for cleaning for Tf-idf, we did not remove stop words. But, we did used stemming which is also good to decrease the number of features. The best result obtained using countvectorizer was using random forest. Generally, it is the Tfidf features that give the best results and the best result using classical approach is SVM using Tf-idf.
#
# In the neural network approach, we used also two feature engineering. First, using Tf-idf like in the classical approach. Second, using word embedding with gloves (3 models) and wordtoVec (1model).
#
# In total, up to 17 machine learning method were used and evaluated. Comparing all these methods used, the best approach is SVM using Tf-idf.

# %% [markdown]
# ## <u>Introduction</u>

# %% [markdown]
# We are living a digital revolution where the amount of data and information we get is exponentially increasing. With the increase and the spreading of these informations through net and social medias, fake informations are increasing and spreading as well. Research from MIT for example has found that fake news travels far faster. For instance,  the study showed that false news stories are 70 percent more likely to be retweeted than true stories. Moreover, Human performance is low in terms of detecting deceptive information [9] with accuracy not higher than chance. Thus, the importance of artificial intelligence to help detect and filter such fake informations.
#
# To  detect false written information, artificial intelligence and specially Natural Language Processing (NLP) is commonly used. Multiple techniques are used to convert words and group of words called (ngram) to features and used then to classify the information.
# In this context, in this project, we will be using (NLP) technique to classify in a supervised approach hotel reviews to truthful and falsful.
# The project will entail reviewing and cleaning the data, extracting relevant features and then fitting the appropriate model which can then produce correct predictions. The accuracy of the predictions will depends heavily on the right data and features selected and the model selected. So, different feature engineering approaches and machine learning models will be tested and compared to find the most appropriate model for predicting falsful and truthful reviews.
#
# We are using data-set from https://myleott.com/op-spam. And the description of the given data is as follows:-
# * 400 truthful positive reviews from TripAdvisor (described in [1])
# * 400 deceptive positive reviews from Mechanical Turk (described in [1])
# * 400 truthful negative reviews from Expedia, Hotels.com, Orbitz, Priceline, TripAdvisor and Yelp (described in [2])
# * 400 deceptive negative reviews from Mechanical Turk (described in [2])
#
# The objective of this project is to identify the falseful and truthful reviews.
#
# * Cleaning and preparation of each review we retrieve from the given folders.
# * Introducing machine learning models
# * Implementation and testing of models
# * Parameters tuning and evaluation

# %% [markdown]
# ### Contents of this project
# <div class="alert alert-warning">
# <pre>* Abstract
# * Introduction
# * Importing Libraries and Data
# * Exploration of reviews and analysis
# * Cleaning and data preprocessing
# * Clssical approach (using countVectorizer)
# 	--Feature selection and engineering
# 	--Models:
# 		+ SVM
# 		+ Decision tree
#         + Logistic Regression
#         + Naive_bayes
#         + Random Forest
#         + KNeighbours
#         + Stochastic Gradient Descent
#
#     --Evalution and parameters tuning
# 		+ Model comparison and precision
# 		+ Parameters tuning (grid search):
#            1. SVM
#            2. Logistc Regression
#            3. Stochastic Gradient Descent
#            4. Random Forest
#
# * Clssical approach (using tf-idf)
# 	--Feature selection and engineering
# 	--Models:
# 		+ SVM
# 		+ Decision tree
#         + Logistic Regression
#         + Naive_bayes
#         + Random Forest
#         + KNeighbours
#         + Stochastic Gradient Descent
#
# 	--Evalution and parameeters tuning
# 		+ Model comparison and precision
# 		+ Parameters tuning (grid search)
#            1. SVM
#            2. Logistc Regression
#            3. Random Forest
# * Results and Conclusion
#
# * Deep learning approach (using tf-idf)
# 	--MLP ( Multi Layer Perceptron)
# 	--Observation
#
# * Deep learning approach (using GloVe)
# 	--MOdel 1:(LSTM 2 layer + CNN + GloVe )
# 	--Model 2:( CNN + GloVe)
#     --Model 3:(LSTM 2 layers)
#     --Comparison with Word2Vec approach
# * Comparision between all the models
# * Conclusion
# * References </pre>
# </div>

# %% [markdown]
# ## Dependencies
# The file "glove.6B.100d.txt" should be downloaded and present in the same folder as the Jupyter notebook. It can be downloaded from https://nlp.stanford.edu/projects/glove/

# %% [markdown]
# ## <u>Importing libraries</u>

# %%
#!pip install parfit
#!pip install texthero

# %%
import os
import re
import numpy as np
import pandas as pd
import texthero as hero
from os import walk
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
from unidecode import unidecode
from IPython.display import Image
import nltk
nltk.download('punkt')
nltk.download("stopwords")
import spacy
from nltk.corpus import stopwords as nltk_stop
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.util import ngrams
import gensim
from gensim.models import word2vec
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn import preprocessing
from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import roc_auc_score
from  sklearn.ensemble  import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV
import parfit.parfit as pf
import tensorflow as tf
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from tensorflow.python.keras import models
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.layers import Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow.keras.backend
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D
from tensorflow.keras.layers import Dropout, GlobalMaxPooling1D, BatchNormalization, LSTM
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Embedding
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Activation, Flatten
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/tsegazabtesfay/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tsegazabtesfay/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## <u>Importing Data</u>

# %% [markdown]
# * <div class="alert alert-info">We started by making a function retreive the data from the folder strutures and generates a dataframe </div>

# %%
def readDataSet(path):
    """
    readDataSet 
        Reads .txt files and creates a DataFrame.
        The function expect the following folderstructure: 
        ./op_spam_v1.4/negative_polarity/deceptive_from_MTurk/fold1/d_hilton_1.txt

    Parameters
    ----------
    path : str
        Root path for the folders containing reviews

    Returns
    -------
    pd.DataFrame
        DataFrame is returned with the columns :
        'classification', 'polarity','source', 'hotel', 'review'
    """
    reviews = []
    for (dirpath, dirnames, filenames) in walk(path):
        for filename in filenames:
            if filename.endswith(".txt"):
                with open(dirpath+os.sep+filename,"r") as txt: 
                    review = txt.read().strip()
                pathsplit = dirpath.split(os.sep)
                reviews.append(
                    [pathsplit[-2].split('_')[0],
                     pathsplit[-3].split('_')[0],
                     pathsplit[-2].split('_')[2],
                     filename.split("_")[1],
                     review])
    return pd.DataFrame(reviews, columns=['classification', 'polarity','source', 'hotel', 'review'])

# %%
#df = readDataSet(f".{os.sep}op_spam_v1.4")
#d_copy = df.copy() # prefer to use copy for keeping the original as it is.
#d_copy["source"].unique()

# %%
path = "./Op_spam.csv"
data = pd.read_csv(path, delimiter=";")
d_copy = data.copy()

# %% [markdown]
# ## <u>Exploration of reviews and analysis</u>
#
# ---

# %% [markdown]
# To explore the reviews, we have used the Python library Pandas in jupyter notebook and jupyter lab.
# <br>
# Pandas allows us to load data as tables and offers a number of functions for easy analysis, such as seeing the number of rows and columns, data types, the number of unique values in different columns and so on.
# </div>

# %%
# for simplicity sake variables are created
classifications = "classification"
polarities = "polarity"
sources = "source"
hotels = "hotel"
reviews = "review"

# %% [markdown]
# <div class="alert alert-info">
#     Let's start by seeing the external information which are readable from the <code>DataFrame</code> before going in to the reviews.
# </div>

# %%
print("Total number of hotels: ",len(d_copy[hotels].unique()), "\n\nAnd their names: \n\n",d_copy[hotels].unique())
# Out:
# Total number of hotels:  20
#
# And their names:
#
#  ['talbott' 'affinia' 'hardrock' 'ambassador' 'intercontinental' 'palmer'
#  'amalfi' 'allegro' 'swissotel' 'knickerbocker' 'homewood' 'sheraton'
#  'omni' 'hyatt' 'conrad' 'fairmont' 'sofitel' 'monaco' 'hilton' 'james']

# %%
print("Number of reviews: ", len(d_copy))
# Out:
# Number of reviews:  1602

# %%
#About 1600 reviews and 5 columns.
d_copy.shape
# Out:
# (1602, 6)

# %%
# The sources for the reviews
print(d_copy[sources].unique())
# Out:
# ['MTurk' 'Web' 'TripAdvisor']

# %%
# The classification it has been given
print(d_copy[classifications].unique())
# Out:
# ['deceptive' 'truthful']

# %%
# And the polarity given by the reviews provider
print(d_copy[polarities].unique())
# Out:
# ['negative' 'positive']

# %%
# The first five rows looks like this:
d_copy.head()
# Out:
#    Unnamed: 0 classification  polarity source     hotel  \
# 0           0      deceptive  negative  MTurk   talbott
# 1           1      deceptive  negative  MTurk   talbott
# 2           2      deceptive  negative  MTurk   affinia
# 3           3      deceptive  negative  MTurk  hardrock
# 4           4      deceptive  negative  MTurk  hardrock
#
#                                               review
# 0  The Talbott Hotel claims to be Chicago's Premi...
# 1  I selected The Talbott for my recent family va...
# 2  I recently stayed at the Affinia Hotel in Chic...
# 3  My husband and I stayed here at the Hard Rock ...
# 4  I stayed at the Hard Rock Hotel in Chicago rec...

# %%
# alternatives to the 3 functions above

# %%
s = d_copy.groupby([sources])[reviews].count()
s.plot.bar(figsize=(8,4))
plt.title("reviews with positive and negatives from each source".upper(), color="b")
plt.ylabel("Number of reviews", color="b")
plt.xlabel("Sources", color="b")
plt.xticks(rotation=0)
plt.show()

d_copy.groupby([sources])[reviews].size()
# Out:
# source
# MTurk          801
# TripAdvisor    401
# Web            400
# Name: review, dtype: int64

# %% [markdown]
# #### Observation
# In this project we have only 1600 reviews, divided from different sources MTurk, TripAdvisor and Web.

# %%
s = d_copy.groupby([sources,polarities])[reviews].count()
s.plot.bar(figsize=(8,4),color = list('brgcmyk'),width = 0.2)
plt.title("reviews with positive and negatives from each source".upper(), color="b")
plt.ylabel("Number of reviews", color="b")
plt.xlabel("Sources", color="b")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# Here we can see that we don't have any positive review from web source and any negative review from TripAdvisor.
# </div>

# %%
s = d_copy.groupby([sources,polarities,classifications])[reviews].count()
s.plot.bar(figsize=(8,4),color = list('brgcmyk'),width = 0.2)
plt.title("reviews from each source - truthful negative/positive and deceptive negative/positve".upper(), color="b")
plt.ylabel("Number of reviews", color="b")
plt.xlabel("Source_Polarity_Classification", color="b")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# In the above bar-graph we have shown where exactly the deceptive and truthful originated from. The picture below summarises the data.
# </div>

# %%
#need to edit the image above
d_copy.groupby([sources,polarities,classifications]).size()
# Out:
# source       polarity  classification
# MTurk        negative  deceptive         401
#              positive  deceptive         400
# TripAdvisor  positive  truthful          401
# Web          negative  truthful          400
# dtype: int64

# %%
# To check if there are some duplicates in the review 
df[df.duplicated()]
# Out:
#      classification  polarity    source hotel  \
# 1258       truthful  negative  polarity     t
# 1509       truthful  negative  polarity     t
# 1517       truthful  negative  polarity     t
# 1581       truthful  negative  polarity     t
#
#                                                  review
# 1258  I'd been searching for a cool, non-chain hotel...
# 1509  The Omni was chosen for it's location whichwor...
# 1517  My daughter and I woke in the morning wanting ...
# 1581  Very disappointed in our stay in Chicago Monoc...

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# From the above we can notice that the data we have is small but do not need a lot of cleaning globally.
# There are four comments that are repeating. In order to clean the data we will remove these comments from the database.
# </div>

# %% [markdown]
# ## <u>Cleaning and data preprocessing </u>

# %% [markdown]
# First step of the cleaning process will be to remove line duplicate, we already found 4 lines that were duplicating during exploring the data step

# %%
d_copy = d_copy.drop_duplicates(keep = 'first',ignore_index = 'True')
d_copy.groupby([sources,polarities,classifications]).size()
# Out:
# source       polarity  classification
# MTurk        negative  deceptive         401
#              positive  deceptive         400
# TripAdvisor  positive  truthful          401
# Web          negative  truthful          400
# dtype: int64

# %%
d_copy
# Out:
#       Unnamed: 0 classification  polarity       source     hotel  \
# 0              0      deceptive  negative        MTurk   talbott
# 1              1      deceptive  negative        MTurk   talbott
# 2              2      deceptive  negative        MTurk   affinia
# 3              3      deceptive  negative        MTurk  hardrock
# 4              4      deceptive  negative        MTurk  hardrock
# ...          ...            ...       ...          ...       ...
# 1597        1597       truthful  positive  TripAdvisor    monaco
# 1598        1598       truthful  positive  TripAdvisor     james
# 1599        1599       truthful  positive  TripAdvisor    monaco
# 1600        1600       truthful  positive  TripAdvisor    monaco
# 1601        1601       truthful  positive  TripAdvisor    hilton
#
#                                                  review
# 0     The Talbott Hotel claims to be Chicago's Premi...
# 1     I selected The Talbott for my recent family va...
# ...

# %% [markdown]
# * Lets now dig deeper into the data and the reviews:
#
# * Stop words are words that are common words that are considered neutral and do not add much meaning to the sentence. A default set of stop words (displayed in the cell above) are provided by The Natural Language Toolkit (NLTK). We used this set of words for processing and cleaning our data by filtring them out from all the comments. This will allow to decrease the number of features and train more accurate model.

# %%
# stop-words we have in english
stop_words_list = []
# Assuming we only have english words in the reviews
stopwords = set(nltk_stop.words("english"))
for i in stopwords:
    stop_words_list.append(i)
print(f"we have {len(stop_words_list)} english-stopwords and some examples of them are:\n{stop_words_list[:20]}" )
# Out:
# we have 179 english-stopwords and some examples of them are:
# ['herself', 'we', 'is', "doesn't", "haven't", 'be', "she's", 'ma', "shouldn't", 'than', 'the', 'him', 'until', 'our', 'weren', 'by', 'through', 'any', 're', 'ours']

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# It is possible that some of these words, has some sentimental meaning and could be important for the classification of reviews.
# </div>

# %% [markdown]
# * Next, we will analyse more these words by counting how much they appear in truthful reviews and in deceptive reviews.

# %%
def stopWordsAnalysis(stopwords):
    n = len(stopwords)
    countwords_ = np.zeros((n,2))
    i = 0
    for word in stopwords:
        deceptive = 0
        truthful = 0
        tick = False
        for r in d_copy[reviews]:
            clas = d_copy[d_copy[reviews]==r].classification.values
            r = r.lower().split()
            for w in r:
                if (w == word):   # in d_copy[hotels].unique() or w == 'rock'):
                    tick = True
            if tick:
                tick = False
                if (clas.any() == 'deceptive'):
                    deceptive = deceptive + 1
                else:
                    truthful = truthful + 1
        countwords_[i, 0] = truthful 
        countwords_[i, 1] = deceptive
        i  = i + 1
    return countwords_
stopWordsCount = stopWordsAnalysis(stop_words_list)

# %%
# We will plot some of the stop words occurences, but all the stop words were analysed,
fig = plt.figure(figsize=(20,4))
plt.plot (stop_words_list[120:160], stopWordsCount[120:160,0], label='Truthfull' )
plt.plot (stop_words_list[120:160], stopWordsCount[120:160,1], label='Decptive')
plt.xlabel('stop_words')
plt.ylabel('occurence')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# After analysing stop words we notice that generally these stop words has neutral feeling (ex: 'and' used around 800 times in truthfull as well as Deceptive reviews). However we find some words that could be used for the classification. Example here: "I, me, my" tend to appear more in deceptive review, while "we, our" tend to be more present in truthfull reviews. May, be false poeple writing deceptive review consider that they did visit the hotel alone (as they are writing the review alone, so they do not consider that they visit with their family so they tend to use I), while real poeple really visiting as family or couple would tend to say we. So, these words should be removed from the stop_word list as they would be important for the classification
# </div>

# %% [markdown]
# * Another cleaning step that we did consider is checking how the presence of the hotel name is affecting the review and to use a sungke wird 'hotelname' as a feature for any hotel name

# %%
def reviewWithOutHotelName():
    '''
    This functions looks prints the number of reviews that did not mention hotel name and their classification
    '''
    count = 0
    tick = False
    truthful = 0
    deceptive = 0
    for r in d_copy[reviews]:
        clas = d_copy[d_copy[reviews]==r].classification.values
        r = r.lower().split()
        for w in r:
            if (w in d_copy[hotels].unique()):
                tick = True
        if tick:
            count += 1
            tick = False
        else:
            if (clas.any() == 'deceptive'):
                deceptive = deceptive + 1
            else:
                truthful = truthful + 1
    print("Reviews without the name of hotel: ",len(d_copy[reviews]) - count)
    print("number of deceptive: ",deceptive)
    print("number of truthful: ",truthful)
reviewWithOutHotelName()
# Out:
# Reviews without the name of hotel:  685
# number of deceptive:  233
# number of truthful:  452

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# The review without hotel name tend to be truthful, more than deceptive. May be the poeple writing deceptive review tend to write again the hotel name may be because their purpose is the hotel reputation, they tend to emphasize on hotel name and this could allow them also to have better ranking of their review when google searching of hotel name. While other poeple, writing truthfull review, their purpose is just to share their feelings and experience. So, we will consider next the name of the hotels in the review as a single word 'hotelname'. Beacause, the hotel names has a similar meaning and we see that they could be important for the ranking
# </div>

# %% [markdown]
# * So, next, in addition to removing the selected stopwords and numbers from all the reviews, to clean the data for the training, we will also consider changing the hotel name in the reviews to the word 'hotelname', to group all hotel names one single feature because it would have same meaning in all the reviews.

# %%
new_stopWords = [word for word in stop_words_list if word not in ['i', 'me', 'my', 'we', 'our','ours', 'on', 'but', 
                                                                        'themselves', 'very',"hadn't",'while','will','other',"you'd",'through']]

# %%
def removeStopwordsPuctuationAln(review_column,stopWords,language="english"):
    """
    remove_stopwords_special_char 
        Makes the reviews lower case,
        removes puncutation, diaeresis, numbers and other special characters,
        as well as removing stopwords using the default nltk_stop words

    Parameters
    ----------
    review_column : pandas.core.series.Series
        Column in the DataFrame which contains the reviews
    language : str, optional
        language of stopwords, by default "english"

    Returns
    -------
    list(str)
        Returns the cleaned reviews as a list
    """
    cleaned_reviews = []
    alphabetic = re.compile(r"[^a-zA-Z\s]") #finds characters not in the range: a-zA-Z and whitespace and '
    singlequote = re.compile(r"((\W)(?:\B|$)|(?:^|\B)(\W))") #finds single quotes not within a word
    for review in review_column:
        new_words = []
        review = unidecode(review) #example: ãБç becomes abc
        review = re.sub(alphabetic," ",review) #example: 2"3can't"/ becomes can't
        review = re.sub(singlequote," ",review) #example: ''' shouldn't '''''' becomes shouldn't
        words = review.lower().split()
        for word in words:
            if(not (word in stopwords) and (word.strip()) and len(word)>1):
                new_words.append(word)
            if ((word in d_copy[hotels].unique()) and (word.strip()) and len(word)>1):
                new_words.append('hotelname')
            else:
                continue
        cleaned_reviews.append(" ".join(new_words))
    return cleaned_reviews

clean_review = removeStopwordsPuctuationAln(d_copy[reviews],new_stopWords)

# %% [markdown]
# * We can see the difference on number of all words in reviews before and after the stopwords cleared out.

# %%
sum_orginal = 0
sum_cleaned = 0
for i in range(len(d_copy)):
    sum_orginal += len(d_copy[reviews][i].split(" "))
    sum_cleaned += len(clean_review[i].split(" "))
print("*"*100)
print("Original words: ", sum_orginal)
print("Without stopwords & alnum: ", sum_cleaned)
print("Difference : ", sum_orginal - sum_cleaned)
# Out:
# ****************************************************************************************************
# Original words:  238967
# Without stopwords & alnum:  117365
# Difference :  121602

# %% [markdown]
# * By using wordcloud we can visualize the most common words from the reviews

# %%
#original reviews

hero.visualization.wordcloud(d_copy['review'], max_words=30,background_color='white')

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# The wordcloud above shows that the most common word is "the" without cleaning the dataset
# </div>

# %%
#reviews without stopwords
hero.visualization.wordcloud(pd.Series(clean_review), max_words=30,background_color='white')

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# After removing the stopwords the word "hotel" becomes the most common word, also after grouping all hotel names to a single word 'hotelname' the 'hotel name' entrer the list of the most common words
# </div>

# %% [markdown]
# * Another important processing step is to group the words having same root into one feature. This is called stemming or Text Normalization and this is a common technic used in NLP. In fact, these words having same root will have similar meaning. So, grouping them in one feature would make more robust model, specially as we have a small data base, so we need fewer number of features. This was done also using the NLTK library and we choosed Porter method....

# %%
def stemReviews(nnStem_reviews):
    """
    stemSentence 
        Using the default nltk Porter Stemmer for text normalization

    Parameters
    ----------
    nnStem_reviews : list(str)
        List of reviews

    Returns
    -------
    list(str)
        returns the reviews after stemming
    """
    cleaned_reviews = []
    porter=PorterStemmer()
    for review in nnStem_reviews:
        token_words=word_tokenize(review)
        stem_sentence=[]
        for word in token_words:
            stem_sentence.append(porter.stem(word))
        cleaned_reviews.append(" ".join(stem_sentence))
    return cleaned_reviews

stem_review = stemReviews(clean_review)

# %% [markdown]
# * We can see the difference of number of all words in reviews after removing stop words and after stemming

# %%
#print(clean_review[0])
#print(reviews_text[0])
vectorizer = CountVectorizer() 
review_words = vectorizer.fit_transform(clean_review)
print('Number of words in the review after removing stop words and before stemming is : ', review_words.shape[1])
#print(vectorizer.vocabulary_)
#print('*'*100)
clean_review_words = vectorizer.fit_transform(stem_review)
print('Number of words in the clean review after stemming is :', clean_review_words.shape[1])
#print(vectorizer.vocabulary_)
print('*'*100)
print('Number of features decreased by ', 100*(review_words.shape[1]-clean_review_words.shape[1])/review_words.shape[1], '%' )
# Out:
# Number of words in the review after removing stop words and before stemming is :  9147
# Number of words in the clean review after stemming is : 6381
# ****************************************************************************************************
# Number of features decreased by  30.23942276156117 %

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# We see a decrease of 30% in number of features. This is quite important result specially as the data set is small to avoid over fitting. In fact, stemming allows to group similar words having similar root and thus generally similar meaning allowing to generate less correlable features.
# </div>

# %% [markdown]
# * top 15 words before and after stemming

# %%
hero.top_words(pd.Series(clean_review))[:20]
# Out:
# hotel        3333
# room         2813
# hotelname    1636
# chicago      1524
# stay         1302
# would         922
# great         864
# staff         836
# service       815
# one           717
# rooms         679
# stayed        664
# us            575
# night         574
# like          557
# get           551
# time          522
# desk          508
# nice          489
# location      482
# dtype: int64

# %%
hero.top_words(pd.Series(stem_review))[:20]
# Out:
# hotel       3642
# room        3494
# stay        2261
# hotelnam    1636
# chicago     1524
# would        922
# servic       871
# great        866
# staff        838
# night        764
# one          733
# bed          688
# get          636
# time         630
# locat        623
# check        617
# like         614
# us           575
# clean        546
# even         522
# dtype: int64

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# We can notice that 'stay' was ranked 4th before stemming and moved to the 3rd place. Similarly 'servic'  root of 'service' moved from 8 to 6. However, we notice that sometimes the stemming do not generate real words or could mix some words with similar root. This is an uncertainty that we will accept as we think it will not have a very big impact on results (actually we compared the results with stemming and without and we found we have slightly better result with stemming).
# </div>

# %% [markdown]
# We implemented also in the next cell, ngramfeatures function which allows to use more than one word as a feature by grouping subsequent words.
#
# Later on, we used the embedded ngram prameter in the sklearn countvectorizer class to simplify the coding

# %% [markdown]
# #### <u>Classifier and Re classes</u>
# Two classes were created to simplify classification process. It will classify the review either truthful or deceptive

# %%
class Classifier:
    Truthful = "truthful".upper()
    Falseful = "deceptive".upper()
class Re:
    def __init__(self, classification, polarity, source, hotel, review):
        """
        Parameters
        ----------
        classification : str
            Classification of the review, either deceptive or thruthful
        polarity : str
            If the review is positive or negative
        source : str
            Where the review was posted
        hotel : str
            The hotel which the review is for
        review : str
            The review
        """
        self.classification = classification
        self.polarity = polarity
        self.source = source
        self.hotel = hotel
        self.review = review
        self.result = self.geter()
        
    def geter(self):
        if(self.classification == "deceptive" and (self.polarity == "negative" or self.polarity == "positive")):
            return Classifier.Falseful
        if(self.classification == "truthful" and(self.polarity == "negative" or self.polarity == "positive")):
            return Classifier.Truthful

# %%
rs = []
for i in range(len(d_copy)):
    rs.append(Re(d_copy["classification"][i], d_copy["polarity"][i],
                 d_copy["source"][i], d_copy["hotel"][i], stem_review[i]))

# %% [markdown]
# The classical approach and the neural network  approach do need different way of features engineering. In this regards, now, we will divide our work in two parts Classical approach and deep learning

# %% [markdown]
# # <u> Classical approach: (using countervectorizer) </u>

# %% [markdown]
# ## <u>Feature selection & Engineering,</u>

# %% [markdown]
# * Models we are going to use do not understand plain text as input and only work with numbers, vectors and matrices. Therefore, we had to find a method to represent the reviews as numbers, more specifically as vectors or matrices to consider as features and use as input to the models. A very popular approach to use in such opinions classification is Bow. BoW features could be represented by frequency or counts of a word or an ensemble of words which is also called ngram. Unigram (one word), bigram (two words) and trigram (three words) could be used. As our dataset is small, we will stop to bigram.
#
# * The first approach we will implement for feature selection is "countervectorizer" in scikit-learn which consider the feature counts. We will also show the use <code>"tf-idf"</code> (Term Frequency-Inverse Document Frequency), which is another type of word embedding, which considers the frequency of appearance of the word in the review, and the inverse document frequency of the word across a set of documents..

# %%
def ngramfeatures(ng_reviews, n=3):
  text = []
  for rev in ng_reviews:
        text.append(rev)
  # first get individual words
  tokenized = str(text).split() 
  # get a list of all the bi-grams
  nGrams = ngrams(tokenized, n) 
  return list(nGrams)
    
features = ngramfeatures(clean_review,3)
print (len(list(features)))
print ((features)[:15])
# Out:
# 117363
# [("['talbott", 'hotelname', 'hotel'), ('hotelname', 'hotel', 'claims'), ('hotel', 'claims', 'chicago'), ('claims', 'chicago', 'premiere'), ('chicago', 'premiere', 'small'), ('premiere', 'small', 'luxury'), ('small', 'luxury', 'hotel'), ('luxury', 'hotel', 'staying'), ('hotel', 'staying', 'experiencing'), ('staying', 'experiencing', 'service'), ('experiencing', 'service', 'environment'), ('service', 'environment', 'hotel'), ('environment', 'hotel', 'general'), ('hotel', 'general', 'say'), ('general', 'say', 'confidence')]

# %% [markdown]
# * Lets began with 70% of data for training and the rest for testing.

# %%
training, test = train_test_split(rs, test_size=0.3, random_state=42)
print("Number of reviews used for training:", len(training))
print("Number of reviews used for testing:",len(test))
# Out:
# Number of reviews used for training: 1121
# Number of reviews used for testing: 481

# %%
train_x = [x.review for x in training]
train_y = [x.result for x in training]

test_x = [x.review for x in test]
test_y = [x.result for x in test]

# %% [markdown]
# #### Vectorization with ngram

# %% [markdown]
# * For the count vectorizer, that we will implement now, it converts a collection of text documents to a matrix of token counts. In our case, it would generate a vocabulary from the cleaned reviews, So the number of features will be equal to the vocabulary size and the value of each feature in each review will be the count of that word or ngram. We use ngram(1,2) which is the collections of 1 word and 2 words.

# %%
vectorizer = CountVectorizer(ngram_range=(1, 2))    #  Apply ngram _1 to 2 words
train_x_vectors = vectorizer.fit_transform(train_x)
test_x_vectors = vectorizer.transform(test_x) # here we don't need to fit, cause it is a test data
#print(train_x_vectors.shape)
#print(vectorizer.get_feature_names()[1050:1100])
#print(vectorizer.vocabulary_)    # the ngram features from all the reviews
#print(train_x[0])  # the cleaned review train number 0
#print(train_x_vectors[0])  # the ngram count vector for that review

# %% [markdown]
# ### Observation:
# Notice that we have 58804 features, while only 1600 review (data).
# We think that our database is small, and it will be very usefull to use more reviews to improve the performance of our classifiers and avoir overfitting. However, it still a good data set as it is not easy to get labeled deceptive review data.

# %% [markdown]
# ## <u> Model Selections  </u>

# %% [markdown]
# * Multiple models could be used for supervised machine learning using classical approaches, we will use seven [11]

# %% [markdown]
# ### <u> MODEL-1: SVM (sklearn) </u>

# %% [markdown]
# SVM is very popular approach and could be used both for linear and non linear classification

# %%
# fiting and predicting svm & prints some sampls, both for the true solution and the predicted ones
clf_svm = svm.SVC(kernel="linear")
clf_svm.fit(train_x_vectors, train_y)
y_pred_svm = clf_svm.predict(test_x_vectors)
for i in range(10):
    print("True solution from dataset: ", test_y[i])
    print("Learned svm: ", clf_svm.predict(test_x_vectors[i])[0])
    print("*"*15)
# Out:
# True solution from dataset:  TRUTHFUL
# Learned svm:  DECEPTIVE
# ***************
# True solution from dataset:  DECEPTIVE
# Learned svm:  DECEPTIVE
# ***************
# True solution from dataset:  DECEPTIVE
# Learned svm:  DECEPTIVE
# ***************
# True solution from dataset:  DECEPTIVE
# Learned svm:  TRUTHFUL
# ***************
# True solution from dataset:  TRUTHFUL
# Learned svm:  TRUTHFUL
# ***************
# True solution from dataset:  TRUTHFUL
# Learned svm:  TRUTHFUL
# ***************
# True solution from dataset:  DECEPTIVE
# Learned svm:  TRUTHFUL
# ***************
# True solution from dataset:  DECEPTIVE
# Learned svm:  DECEPTIVE
# ***************
# True solution from dataset:  DECEPTIVE
# Learned svm:  DECEPTIVE
# ***************
# True solution from dataset:  TRUTHFUL
# Learned svm:  TRUTHFUL
# ***************

# %%
# and see the score of this model
clf_svm_score=clf_svm.score(test_x_vectors, test_y)
print(clf_svm_score)
#svm_probs = clf_svm.predict_proba(test_x_vectors)
#svm_probs = svm_probs[:, 1]
#svm_precision, svm_recall, _ = precision_recall_curve(test_y, svm_probs, pos_label='TRUTHFUL')
#svm_auc = auc(svm_recall, svm_precision)
#print(svm_auc)
svm_auc = None
# Out:
# 0.8830897703549061

# %% [markdown]
# ### <u> MODEL-2: Decision Tree  (sklearn) </u>

# %% [markdown]
# Produces a sequence of rules that can be used to classify the data

# %%
clf_dec = DecisionTreeClassifier()
clf_dec.fit(train_x_vectors, train_y)
y_pred_dec = clf_dec.predict(test_x_vectors)

# %%
# See simple result
for i in range(3): 
    print("Predicted solution: ",clf_dec.predict(test_x_vectors[i]))
    print("True solution: ", test_y[i])
# Out:
# Predicted solution:  ['DECEPTIVE']
# True solution:  DECEPTIVE
# Predicted solution:  ['DECEPTIVE']
# True solution:  DECEPTIVE
# Predicted solution:  ['DECEPTIVE']
# True solution:  DECEPTIVE

# %%
clf_dec_score = clf_dec.score(test_x_vectors, test_y)
print(clf_dec_score)
dec_probs = clf_dec.predict_proba(test_x_vectors)
dec_probs = dec_probs[:, 1]
dec_precision, dec_recall, _ = precision_recall_curve(test_y, dec_probs, pos_label='TRUTHFUL')
dec_auc = auc(dec_recall, dec_precision)
print(dec_auc)
# Out:
# 0.7494780793319415
# 0.8244444066099254

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# In decisionTree we have not performed a gridsearch. The reason is, that we saw the probability of this model giving us better results than the svm-model results is very low, since we only got 69% at this level and the fact that we have very limted data. Thus, the decision-tree-classifier can not compare to svm. Vut, we will run next Random Forest which is based on running and averaging multipe decision trees.
# </div>

# %% [markdown]
# ### <u> MODEL-3: Logistic Regression (sklearn) </u>

# %% [markdown]
# This method uses logistic regrssion function

# %%
clf_lg = LogisticRegression()
clf_lg.fit(train_x_vectors, train_y)
y_pred_lg = clf_lg.predict(test_x_vectors)
clf_lg_score = clf_lg.score(test_x_vectors, test_y)
print(clf_lg_score)
lg_probs = clf_lg.predict_proba(test_x_vectors)
lg_probs = lg_probs[:, 1]
lg_precision, lg_recall, _ = precision_recall_curve(test_y, lg_probs, pos_label='TRUTHFUL')
lg_auc = auc(lg_recall, lg_precision)
# Out:
# 0.8830897703549061

# %% [markdown]
# ### <u> MODEL-4: Naive_bayes (sklearn) </u>
#
# ---

# %% [markdown]
# Calculate class probability using Byes theorem assumping each feature is independent from the others and choose the most probable result

# %%
from sklearn.naive_bayes import GaussianNB
clf_gnb = GaussianNB()
clf_gnb.fit(train_x_vectors.toarray(), train_y)
y_pred_gnb = clf_gnb.predict(test_x_vectors.toarray())
clf_gnb_score = clf_gnb.score(test_x_vectors.toarray(), test_y)
print(clf_gnb_score)

gnb_probs = clf_gnb.predict_proba(test_x_vectors.toarray())
gnb_probs = gnb_probs[:, 1]
gnb_precision, gnb_recall, _ = precision_recall_curve(test_y, gnb_probs, pos_label='TRUTHFUL')
gnb_auc = auc(gnb_recall, gnb_precision)
# Out:
# 0.7828810020876826

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# Yhe algorithm was better that the decision tree as expected as it produces a multiple number of decision tree and do the average to improve the performance and avoid over fitting. But, still the score is lower than other algorithm. So, we had not done a gridsearch on this model. In fact, we saw the probability of this model giving us better results than the svm-model results is very low, since we only got at this level and the fact that we have very limted data.
# </div>

# %% [markdown]
# ### <u> MODEL-5: Random Forest (sklearn) </u>

# %% [markdown]
# Averages the result from a number of decision trees on various sub-samples of datasets to improve the predictive accuracy of the model

# %%
clf_rfc = RandomForestClassifier(n_estimators = 1000, criterion = 'entropy', random_state = 0)
# Predicting the Test set results
clf_rfc.fit(train_x_vectors, train_y)
y_pred_rfc = clf_rfc.predict(test_x_vectors)
clf_rfc_score = clf_rfc.score(test_x_vectors, test_y)
print(clf_rfc_score)

rfc_probs = clf_rfc.predict_proba(test_x_vectors.toarray())
rfc_probs = rfc_probs[:, 1]
rfc_precision, rfc_recall, _ = precision_recall_curve(test_y, rfc_probs, pos_label='TRUTHFUL')
rfc_auc = auc(rfc_recall, rfc_precision)
# Out:
# 0.8747390396659708

# %% [markdown]
# ### <u> MODEL-6: KNeighbors (sklearn) </u>
# KNeighborsClassifier classifies the data using its K nearest (distance) neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
clf_neigh = KNeighborsClassifier(n_neighbors=30)
clf_neigh.fit(train_x_vectors, train_y)
y_pred_neigh = clf_neigh.predict(test_x_vectors)
clf_neigh_score = clf_neigh.score(test_x_vectors, test_y)
print(clf_neigh_score)
neigh_probs = clf_neigh.predict_proba(test_x_vectors)
neigh_probs = neigh_probs[:, 1]
neigh_precision, neigh_recall, _ = precision_recall_curve(test_y, neigh_probs, pos_label='TRUTHFUL')
neigh_auc = auc(neigh_recall, neigh_precision)
# Out:
# 0.47390396659707723

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# Using KNeighborsClassifier, you can notice that the model is not working. In fact, KNeighborsClassifier classifies the data using its K nearest (distance) neighbor. Somehow this algorithm fails using vectorizer features, (which mean a vector of the count of the vocabulary in the review). Which mean, that the distance between these vectors are not meaningful for our classification. We will try later on using Tf-idf may be we get better results.
# </div>

# %% [markdown]
# ### <u> MODEL-7: Stochastic gradient descent (sklearn) </u>

# %%
from sklearn.linear_model import SGDClassifier
clf_sgd = SGDClassifier()
clf_sgd.fit(train_x_vectors, train_y)
y_pred_sgd = clf_sgd.predict(test_x_vectors)
clf_sgd_score = clf_sgd.score(test_x_vectors, test_y)
print(clf_sgd_score)
#auc_sc_score = roc_auc_score(binarizer.transform(test_y), binarizer.transform(y_pred_sgd))

#sgd_probs = clf_sgd.predict_proba(test_x_vectors)
#sgd_probs = sgd_probs[:, 1]
#sgd_precision, sgd_recall, _ = precision_recall_curve(test_y, sgd_probs, pos_label='TRUTHFUL')
#sgd_auc = auc(sgd_recall, sgd_precision)
sgd_auc = None
# Out:
# 0.8747390396659708

# %% [markdown]
# ## <u> Evaluation and parameters tuning </u>

# %% [markdown]
# ### <u> Model comparison and Precision </u>

# %% [markdown]
# The two scoring parameters that we chose to use are
#  - Accuracy: (True Positive + True Negative) / Total Population (ratio of correctly predicted observation to the total observations)
#  - F1-Score: (2 x Precision x Recall) / (Precision + Recall) ( weighted average of Precision and Recall)
#  - Auc score: Area Under the Curve (AUC) of Receiver Characteristic Operator (ROC), The higher the AUC, the better the performance of the model at distinguishing between the positive and negative classes.
#
# Precision: true positive / (true positive +false positive) (When a positive value is predicted, how often is the prediction correct)
#
# Recall: true positive / (true positive +false negative) (When the actual value is positive, how often is the prediction correct)

# %%
fig = plt.figure(figsize=(15,4))


binarizer = MultiLabelBinarizer()
binarizer.fit(test_y)
method = ['Support Vector Machine','decision tree','logistic regression','Naïve Bayes','Random Forest','K-Nearest Neighbours','stoc gradient descent']
y_pred = [y_pred_svm, y_pred_dec, y_pred_lg, y_pred_gnb, y_pred_rfc, y_pred_neigh, y_pred_sgd]
f1_sc = []
acc_sc = []
auc_sc = [svm_auc,dec_auc, lg_auc, gnb_auc,rfc_auc, neigh_auc, sgd_auc]
 

i = 0
for item in y_pred:
    f1_sc.append([f1_score(binarizer.transform(test_y), binarizer.transform(item),  average='macro')])
    acc_sc.append([accuracy_score(binarizer.transform(test_y), binarizer.transform(item))])
    print("Method: %s f1 score: %s accuracy_score: %s auc_score: %s" % (method[i], f1_sc[i], acc_sc[i], auc_sc[i]))
    i = i+1

plt.plot(method,f1_sc, '-*', label='f1_score' )
plt.plot(method,acc_sc, '-*', label='accuracy' )
plt.plot(method,auc_sc, '-*', label='auc score' )

plt.yticks([0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1])
plt.legend()
plt.grid()
plt.show()
# Out:
# Method: Support Vector Machine f1 score: [0.8924886888353863] accuracy_score: [0.8830897703549061] auc_score: None
# Method: decision tree f1 score: [0.7684424079191298] accuracy_score: [0.7494780793319415] auc_score: 0.8244444066099254
# Method: logistic regression f1 score: [0.8924886888353863] accuracy_score: [0.8830897703549061] auc_score: 0.9606474863091885
# Method: Naïve Bayes f1 score: [0.8003361364085744] accuracy_score: [0.7828810020876826] auc_score: 0.8496300990820824
# Method: Random Forest f1 score: [0.885107569998954] accuracy_score: [0.8747390396659708] auc_score: 0.9629171367418012
# Method: K-Nearest Neighbours f1 score: [0.40486307837582625] accuracy_score: [0.47390396659707723] auc_score: 0.7609679120279735
# Method: stoc gradient descent f1 score: [0.8848093094664854] accuracy_score: [0.8747390396659708] auc_score: None

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# All the models gives good scores above 0.7 except K-nearest neighbour wich in this case is like random guess probably in this space there is no meaning to use distance between count_vector features.
#
# The four best models will be fine tuned to find the best parameters
# </div>

# %% [markdown]
# ### Parameters tuning (GridSearch)

# %% [markdown]
# The three best algorithms are SVM, logistic regression and stoc gradient descent with a fit superior to 85%.
# We will next fine tune the parameters in these algorithms to find the parameters providing the best results

# %% [markdown]
# #### SVM
# <div class="alert alert-warning">
# </div>

# %% [markdown]
# * Now lets take use of greadsearch by cross-validation to find a better result.

# %%
def testingForGridSearchForSVM(trainX, trainY, testX, testY ):    
    print(__doc__)

    # Set the parameters by cross-validation
    tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-2, 1e-3],
                         'C': [10, 100, 1000, 10000]},
                        {'kernel': ['linear'], 'C': [0.001, 0.1, 1, 10]}]
    scores = ['precision', 'recall']

    for score in scores:
        print("# Tuning hyper-parameters for %s" % score)
        print()
        clf = GridSearchCV(
            SVC(), tuned_parameters, scoring = "%s_macro" % score
        )
        clf.fit(trainX, trainY)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = testY, clf.predict(testX)
        print(classification_report(y_true, y_pred))
        print()
testingForGridSearchForSVM(train_x_vectors, train_y, test_x_vectors, test_y)
# Out:
# Automatically created module for IPython interactive environment
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.794 (+/-0.047) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.860 (+/-0.053) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.794 (+/-0.047) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.854 (+/-0.037) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.794 (+/-0.047) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.854 (+/-0.037) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.794 (+/-0.047) for {'C': 10000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.854 (+/-0.037) for {'C': 10000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.792 (+/-0.058) for {'C': 0.001, 'kernel': 'linear'}
# 0.846 (+/-0.029) for {'C': 0.1, 'kernel': 'linear'}
# 0.846 (+/-0.029) for {'C': 1, 'kernel': 'linear'}
# 0.846 (+/-0.029) for {'C': 10, 'kernel': 'linear'}
#
# ...

# %%
clf_svm_opt = svm.SVC(C = 10, gamma = 0.001, kernel = 'rbf')
clf_svm_opt.fit(train_x_vectors, train_y)
y_pred_svm_opt = clf_svm_opt.predict(test_x_vectors)
clf_svm_score_opt = clf_svm_opt.score(test_x_vectors, test_y)
print(clf_svm_score_opt)
binarizer = MultiLabelBinarizer()
binarizer.fit(test_y)
f1_score_opt_svm =f1_score(binarizer.transform(test_y), binarizer.transform(y_pred_svm_opt),  average='macro') 
accuracy_score_opt_svm = accuracy_score(binarizer.transform(test_y), binarizer.transform(y_pred_svm_opt))
print("f1 score: %s accuracy_score: %s" % (f1_score_opt_svm, accuracy_score_opt_svm))
# Out:
# 0.8956158663883089
# f1 score: 0.9042133068312587 accuracy_score: 0.8956158663883089

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# Here, we have an example of the best parameters would use to come up to 88/89% accuracy. And this accuracy is ok since we have very small data to train the model.
# </div>

# %% [markdown]
# #### Logistic Regression
# <div class="alert alert-warning">
# </div>

# %%
# example of grid searching key hyperparametres for logistic regression
def testingForGridsLG(trainX, trainY, testX, testY ):
    
    # define models and parameters
    model = LogisticRegression()
    solvers = ['newton-cg', 'lbfgs', 'liblinear']
    penalty = ['l2']
    c_values = [100, 10, 1.0, 0.1, 0.01]
    
    # define grid search
    grid = dict(solver=solvers,penalty=penalty,C=c_values)
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
    grid_result = grid_search.fit(trainX, trainY)
    # summarize results
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
        y_true, y_pred = testY, grid_search.predict(testX)
    print("*"*77)
    print(classification_report(y_true, y_pred))

testingForGridsLG(train_x_vectors, train_y, test_x_vectors, test_y)
# Out:
# Best: 0.863908 using {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.862422 (0.031494) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.862422 (0.031494) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.859736 (0.032902) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.863312 (0.031480) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.863312 (0.031480) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.861524 (0.032377) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.863908 (0.031097) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.863908 (0.031097) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.861527 (0.030131) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.859417 (0.031729) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.859417 (0.031729) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# ...

# %%
clf_lg_opt = LogisticRegression(C= 100,solver = 'newton-cg' )
clf_lg_opt.fit(train_x_vectors, train_y)
y_pred_lg_opt = clf_lg_opt.predict(test_x_vectors)
clf_lg_score_opt = clf_lg_opt.score(test_x_vectors, test_y)
print(clf_lg_score_opt)
binarizer = MultiLabelBinarizer()
binarizer.fit(test_y)
f1_score_opt_lg =f1_score(binarizer.transform(test_y), binarizer.transform(y_pred_lg_opt),  average='macro') 
accuracy_score_opt_lg = accuracy_score(binarizer.transform(test_y), binarizer.transform(y_pred_lg_opt))
print("f1 score: %s accuracy_score: %s" % (f1_score_opt_lg, accuracy_score_opt_lg))
# Out:
# 0.8851774530271399
# f1 score: 0.8944400348310997 accuracy_score: 0.8851774530271399

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# We see that the accuracy we are getting is lower than the previous one which is tested by the use of default parameters. In here, we see that we can get the minimum accuracy(assuming with the use of the parameters from <code>testingForGridsLG</code>) but the maximum can be 90 or greater. So the model is comparable with other good models..
# </div>

# %% [markdown]
# #### <u> Stochastic gradient descent </u>

# %%
grid = {
    'alpha': [1e-4, 1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3], # learning rate
    'loss': ['log'], # logistic regression,
    'penalty': ['l2'],
    'n_jobs': [-1]
}

paramGrid = ParameterGrid(grid)
bestModel, bestScore, allModels, allScores = pf.bestFit(SGDClassifier, paramGrid,
           train_x_vectors, train_y, test_x_vectors, test_y,
           metric = accuracy_score, 
           scoreLabel = 'accuracy')           
#"AUC"
print(bestModel, bestScore)
# Out:
# -------------FITTING MODELS-------------
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   8 | elapsed:    0.9s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.9s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    0.9s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    0.0s remaining:    0.0s
# -------------SCORING MODELS-------------
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.6s finished
# ...

# %%
clf_sgd_opt = SGDClassifier(alpha=0.01)
clf_sgd_opt.fit(train_x_vectors, train_y)
y_pred_sgd_opt = clf_sgd_opt.predict(test_x_vectors)
clf_sgd_score_opt = clf_sgd_opt.score(test_x_vectors, test_y)
print(clf_sgd_score_opt)
binarizer = MultiLabelBinarizer()
binarizer.fit(test_y)
f1_score_opt_sgd =f1_score(binarizer.transform(test_y), binarizer.transform(y_pred_sgd_opt),  average='macro') 
accuracy_score_opt_sgd = accuracy_score(binarizer.transform(test_y), binarizer.transform(y_pred_sgd_opt))
print("f1 score: %s accuracy_score: %s" % (f1_score_opt_sgd, accuracy_score_opt_sgd))
# Out:
# 0.8872651356993737
# f1 score: 0.8966788702928871 accuracy_score: 0.8872651356993737

# %%
def testingForGridsRF(trainX, trainY, testX, testY ):
  rf = RandomForestClassifier(random_state = 42)
  n_estimators = [2000]
  max_features = ['auto', 'sqrt']
  max_depth = [110]   # int(x) for x in np.linspace(10, 110, num = 2)]
  max_depth.append(None)
  min_samples_split = [2, 10]
  min_samples_leaf = [2]
  # Method of selecting samples for training each tree
  bootstrap = [False]
  # Create the random grid
  random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
  pprint(random_grid)
  print("*"*77)
  # Use the random grid to search for best hyperparameters
  rf = RandomForestClassifier()
  # Random search of parameters, using 3 fold cross validation, 
  # search across 100 different combinations, and use all available cores
  rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
  # Fit the random search model
  grid_result = rf_random.fit(trainX, trainY)
  rf_random.best_params_
  # summarize results
  print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
  means = grid_result.cv_results_['mean_test_score']
  stds = grid_result.cv_results_['std_test_score']
  params = grid_result.cv_results_['params']
  for mean, stdev, param in zip(means, stds, params):
      print("%f (%f) with: %r" % (mean, stdev, param))
      y_true, y_pred = test_y, rf_random.predict(testX)
  print("*"*77)
  print(classification_report(testY, y_pred))

testingForGridsRF(train_x_vectors, train_y, test_x_vectors, test_y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# {'bootstrap': [False],
#  'max_depth': [110, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [2],
#  'min_samples_split': [2, 10],
#  'n_estimators': [2000]}
# *****************************************************************************
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [Parallel(n_jobs=-1)]: Done  14 out of  24 | elapsed:  1.2min remaining:   52.5s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:  1.3min finished
# Best: 0.867501 using {'n_estimators': 2000, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 110, 'bootstrap': False}
# 0.861229 (0.008412) with: {'n_estimators': 2000, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 110, 'bootstrap': False}
# ...

# %%
clf_rfc_opt = RandomForestClassifier(n_estimators= 2000, min_samples_split= 2, min_samples_leaf= 2, max_features= 'sqrt', max_depth= None, bootstrap= False)
clf_rfc_opt.fit(train_x_vectors, train_y)
y_pred_rfc_opt = clf_rfc_opt.predict(test_x_vectors)
clf_rfc_score_opt = clf_rfc_opt.score(test_x_vectors, test_y)
print(clf_rfc_score_opt)
binarizer = MultiLabelBinarizer()
binarizer.fit(test_y)
f1_score_opt_rfc =f1_score(binarizer.transform(test_y), binarizer.transform(y_pred_rfc_opt),  average='macro') 
accuracy_score_opt_rfc = accuracy_score(binarizer.transform(test_y), binarizer.transform(y_pred_rfc_opt))
print("f1 score: %s accuracy_score: %s" % (f1_score_opt_rfc, accuracy_score_opt_rfc))
# Out:
# 0.8789144050104384
# f1 score: 0.8887144601430316 accuracy_score: 0.8789144050104384

# %%
method_tuned = ['Support Vector Machine','logistic regression','random forest','stoc gradient descent']
y_pred = [y_pred_svm_opt, y_pred_lg_opt,y_pred_rfc_opt, y_pred_sgd_opt]
f1_sc_opt = [f1_score_opt_svm,f1_score_opt_lg,f1_score_opt_rfc,f1_score_opt_sgd]
acc_sc_opt = [accuracy_score_opt_svm,accuracy_score_opt_lg,accuracy_score_opt_rfc, accuracy_score_opt_sgd]

plt.plot(method_tuned,f1_sc_opt,'-*',  label='f1_score' )
plt.plot(method_tuned,acc_sc_opt,'-*',  label='accuracy' )
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# After optimising the parameters, we have a global improvement of the different score metrics. While the three approach are comparables, the random forest is slightly better than the other
# </div>

# %% [markdown]
# # <u> Classical approach (using tf_idf) </u>

# %% [markdown]
# ## Feature selection & engineering

# %% [markdown]
# We will use now tf-idf for feature engineering, Tf-idf stands for term frequency - inverse document frequency. The algorithm calculates first out a word frequency, "tf", for each word in a review and then weight this frequency with a number based on how often the word occurs over all the reviews, "idf". The word frequency is just the ratio between the number of occurrences of a word in a review and the total number of words in the same review. The inverse document frequency for one word is the logarithm of the ratio between the number of reviews and the number of reviews that contain the word. The word frequency is weighted by document frequency by multiplying the two numbers together. What we end up with is a number that says how much a word has been used in a review, relative to how often the word is used in all the reviews.
#
# An important aspect of the tf_idf that we do not need stop words as these words having high frequency in all reviews, so low weight for the feature.
# Although stemming is not necessary we noticed similar results with stemming and without. But, the use stemming will reduce computation time as we are reducing the number of features. So, we will use stemming.

# %%
# In this cell we clean the data using ponctuation removing and stemming, this is not needed when using Tfidf as Tfidf takes
# into the frequency of presence of each word in the review and in the 
clean_review_Tfidf = removeStopwordsPuctuationAln(d_copy[reviews], stopWords = [])
stem_review_Tfidf = stemReviews(clean_review_Tfidf)

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 2)) 
X = tfidf.fit_transform(stem_review_Tfidf)  #uncomment if we want to use the stemmed review, we noticed a slight better fit when we use the non stemmed reviews
#X = tfidf.fit_transform(d_copy[reviews][:])
X_train, X_test, y_train, y_test = train_test_split(X, d_copy[classifications][:], random_state=42, test_size=0.3, shuffle=True)

# %% [markdown]
# ### <u> MODEL-1: SVM (sklearn) </u>

# %%
clf_svm_Tfidf = svm.SVC(kernel="linear")
clf_svm_Tfidf.fit(X_train, y_train)
y_pred_svm_Tfidf = clf_svm_Tfidf.predict(X_test)
clf_svm_Tfidf_score=clf_svm_Tfidf.score(X_test, y_test)
print(clf_svm_Tfidf_score)
#svm_Tfidf_probs = clf_svm_Tfidf.predict_proba(X_test)
#svm_Tfidf_probs = svm_Tfidf_probs[:, 1]
#svm_Tfidf_precision, dec_Tfidf_recall, _ = precision_recall_curve(y_test, svm_Tfidf_probs, pos_label='truthful')
#svm_Tfidf_auc = auc(svm_Tfidf_recall, svm_Tfidf_precision)
# Out:
# 0.8997912317327766

# %% [markdown]
# ### <u> MODEL-2: Decision Tree  (sklearn) </u>

# %%
clf_dec_Tfidf = DecisionTreeClassifier()
clf_dec_Tfidf.fit(X_train, y_train)
y_pred_dec_Tfidf = clf_dec_Tfidf.predict(X_test)
clf_dec_score_Tfidf = clf_dec_Tfidf.score(X_test, y_test)
print(clf_dec_score_Tfidf)
dec_Tfidf_probs = clf_dec_Tfidf.predict_proba(X_test)
dec_Tfidf_probs = dec_Tfidf_probs[:, 1]
dec_Tfidf_precision, dec_Tfidf_recall, _ = precision_recall_curve(y_test, dec_Tfidf_probs, pos_label='truthful')
dec_Tfidf_auc = auc(dec_Tfidf_recall, dec_Tfidf_precision)
# Out:
# 0.7118997912317327

# %% [markdown]
# ### <u> MODEL-3: Logistic Regression (sklearn) </u>

# %%
clf_lr_Tfidf = LogisticRegressionCV(cv=5,
                           scoring="accuracy",
                           random_state=0,
                           n_jobs=-1,
                           verbose=3,
                           max_iter=300)
clf_lr_Tfidf.fit(X_train, y_train)
y_pred_lr_Tfidf = clf_lr_Tfidf.predict(X_test)
clf_lr_Tfidf_score = clf_lr_Tfidf.score(X_test, y_test)
print(clf_lr_Tfidf_score)
lr_Tfidf_probs = clf_lr_Tfidf.predict_proba(X_test)
lr_Tfidf_probs = lr_Tfidf_probs[:, 1]
lr_Tfidf_precision, lr_Tfidf_recall, _ = precision_recall_curve(y_test, lr_Tfidf_probs, pos_label='truthful')
lr_Tfidf_auc = auc(lr_Tfidf_recall, lr_Tfidf_precision)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   27.1s remaining:   40.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   30.9s finished
# 0.906054279749478

# %% [markdown]
# ### <u> MODEL-4: Naive_bayes (sklearn) </u>

# %%
clf_gnb_Tfidf = GaussianNB()
clf_gnb_Tfidf.fit(X_train.toarray(), y_train)
y_pred_gnb_Tfidf = clf_gnb_Tfidf.predict(X_test.toarray())
clf_gnb_Tfidf_score = clf_gnb_Tfidf.score(X_test.toarray(), y_test)
print(clf_gnb_Tfidf_score)

gnb_Tfidf_probs = clf_gnb_Tfidf.predict_proba(X_test.toarray())
gnb_Tfidf_probs = gnb_Tfidf_probs[:, 1]
gnb_Tfidf_precision, gnb_Tfidf_recall, _ = precision_recall_curve(y_test, gnb_Tfidf_probs, pos_label='truthful')
gnb_Tfidf_auc = auc(gnb_Tfidf_recall, gnb_Tfidf_precision)
# Out:
# 0.7724425887265136

# %% [markdown]
# ### <u> MODEL-5: Random Forest (sklearn) </u>

# %%
clf_rfc_Tfidf = RandomForestClassifier(n_estimators = 2000, criterion = 'entropy', random_state = 0)
# Predicting the Test set results
clf_rfc_Tfidf.fit(X_train, y_train)
y_pred_rfc_Tfidf = clf_rfc_Tfidf.predict(X_test)
clf_rfc_Tfidf_score = clf_rfc_Tfidf.score(X_test, y_test)
print(clf_rfc_Tfidf_score)
rfc_Tfidf_probs = clf_rfc_Tfidf.predict_proba(X_test)
rfc_Tfidf_probs = rfc_Tfidf_probs[:, 1]
rfc_Tfidf_precision, rfc_Tfidf_recall, _ = precision_recall_curve(y_test, rfc_Tfidf_probs, pos_label='truthful')
rfc_Tfidf_auc = auc(rfc_Tfidf_recall, rfc_Tfidf_precision)
# Out:
# 0.8935281837160751

# %% [markdown]
# ### <u> MODEL-6: KNeighbors (sklearn) </u>

# %%
clf_neigh_Tfidf = KNeighborsClassifier(n_neighbors=5)
clf_neigh_Tfidf.fit(X_train, y_train)
y_pred_neigh_Tfidf = clf_neigh_Tfidf.predict(X_test)
clf_neigh_Tfidf_score = clf_neigh_Tfidf.score(X_test, y_test)
print(clf_neigh_Tfidf_score)
neigh_Tfidf_probs = clf_neigh_Tfidf.predict_proba(X_test)
neigh_Tfidf_probs = neigh_Tfidf_probs[:, 1]
neigh_Tfidf_precision, neigh_Tfidf_recall, _ = precision_recall_curve(y_test, neigh_Tfidf_probs, pos_label='truthful')
neigh_Tfidf_auc = auc(neigh_Tfidf_recall, neigh_Tfidf_precision)
# Out:
# 0.7202505219206681

# %% [markdown]
# ### <u> MODEL-7: Stochastic gradient descent (sklearn) </u>

# %%
clf_sgd_Tfidf = SGDClassifier()
clf_sgd_Tfidf.fit(X_train, y_train)
y_pred_sgd_Tfidf = clf_sgd_Tfidf.predict(X_test)
clf_sgd_Tfidf_score = clf_sgd_Tfidf.score(X_test, y_test)
print(clf_sgd_Tfidf_score)
# Out:
# 0.9018789144050104

# %% [markdown]
# ## <u> Evaluation and parameters tuning </u>

# %% [markdown]
# ### <u> Model comparison and Precision </u>

# %%
fig = plt.figure(figsize=(15,4))
binarizer = MultiLabelBinarizer()
binarizer.fit(y_test)
method = ['Support Vector Machine','decision tree','logistic regression','Naïve Bayes','Random Forest','K-Nearest Neighbours','stoc gradient descent']
y_pred_Tfidf = [y_pred_svm_Tfidf, y_pred_dec_Tfidf, y_pred_lr_Tfidf, y_pred_gnb_Tfidf, y_pred_rfc_Tfidf, y_pred_neigh_Tfidf, y_pred_sgd_Tfidf]
auc_sc_Tfidf = [None,dec_Tfidf_auc, lr_Tfidf_auc, gnb_Tfidf_auc,rfc_Tfidf_auc, neigh_Tfidf_auc, None]

f1_sc_Tfidf = []
acc_sc_Tfidf = []
i = 0
for item in y_pred_Tfidf:
    f1_sc_Tfidf.append([f1_score(binarizer.transform(y_test), binarizer.transform(item),  average='macro')])
    acc_sc_Tfidf.append([accuracy_score(binarizer.transform(y_test), binarizer.transform(item))])
    print("Method: %s f1 score: %s accuracy_score: %s auc_score: %s" % (method[i], f1_sc_Tfidf[i], acc_sc_Tfidf[i], auc_sc_Tfidf[i]))

    i = i+1
plt.plot(method,f1_sc_Tfidf, '-*', label='f1_score' )
plt.plot(method,acc_sc_Tfidf,'-*',  label='accuracy' )
plt.plot(method,auc_sc_Tfidf, '-*', label='auc score' )
plt.yticks([0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1])
plt.legend()
plt.grid()
plt.show()
# Out:
# Method: Support Vector Machine f1 score: [0.9076654443862407] accuracy_score: [0.8997912317327766] auc_score: None
# Method: decision tree f1 score: [0.735747410997594] accuracy_score: [0.7118997912317327] auc_score: 0.7986901916374549
# Method: logistic regression f1 score: [0.9135804488647515] accuracy_score: [0.906054279749478] auc_score: 0.9692021409329244
# Method: Naïve Bayes f1 score: [0.7893919107147807] accuracy_score: [0.7724425887265136] auc_score: 0.8402102046692349
# Method: Random Forest f1 score: [0.9020578420467186] accuracy_score: [0.8935281837160751] auc_score: 0.9665655590300939
# Method: K-Nearest Neighbours f1 score: [0.7421690202478947] accuracy_score: [0.7202505219206681] auc_score: 0.8321029906461068
# Method: stoc gradient descent f1 score: [0.9097395799254072] accuracy_score: [0.9018789144050104] auc_score: None

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# All the models accuracy now are above 0.7.
# Even, K-nearest neighbour which was not working has much better score now. And, the best fitting models before are now better and three of them has accuracy superior to 0.9.
#
# While stochastic gradient descent method and random forest has avery good scores. Stochastic gradient is not very stable and its score change depending on random initial condition and Random forest is used now with 2000 tree. So, it will have just slight improvement. But, as we are using the stop words also the number of features is quite high and the computational time of random forest is quite high with high number of trees.
#
# So, we will only use SVM and logistic regression for parameters optimisation.
# </div>

# %% [markdown]
# ### Parameters tuning and precision (GridSearch)
# We will now do a gridsearch to optimise the parameters of best models

# %% [markdown]
# #### SVM

# %%
testingForGridSearchForSVM(X_train, y_train, X_test, y_test)
# Out:
# Automatically created module for IPython interactive environment
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.659 (+/-0.403) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.256 (+/-0.002) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.884 (+/-0.046) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.660 (+/-0.403) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.884 (+/-0.046) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.884 (+/-0.046) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.884 (+/-0.046) for {'C': 10000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.884 (+/-0.046) for {'C': 10000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.256 (+/-0.002) for {'C': 0.001, 'kernel': 'linear'}
# 0.256 (+/-0.002) for {'C': 0.1, 'kernel': 'linear'}
# 0.883 (+/-0.044) for {'C': 1, 'kernel': 'linear'}
# 0.884 (+/-0.046) for {'C': 10, 'kernel': 'linear'}
#
# ...

# %%
clf_svm_Tfidf_opt = svm.SVC(C = 1, gamma = 0.01, kernel = 'linear')
clf_svm_Tfidf_opt.fit(X_train, y_train)
y_pred_svm_Tfidf_opt = clf_svm_Tfidf_opt.predict(X_test)
clf_svm_Tfidf_score_opt = clf_svm_Tfidf_opt.score(X_test, y_test)
print(clf_svm_Tfidf_score_opt)
binarizer = MultiLabelBinarizer()
binarizer.fit(y_test)
f1_score_Tfidf_opt_svm =f1_score(binarizer.transform(y_test), binarizer.transform(y_pred_svm_Tfidf_opt),  average='macro') 
accuracy_score_Tfidf_opt_svm = accuracy_score(binarizer.transform(y_test), binarizer.transform(y_pred_svm_Tfidf_opt))
print("f1 score: %s accuracy_score: %s" % (f1_score_Tfidf_opt_svm, accuracy_score_Tfidf_opt_svm))
# Out:
# 0.8997912317327766
# f1 score: 0.9076654443862407 accuracy_score: 0.8997912317327766

# %% [markdown]
# #### Logistic regression

# %%
testingForGridsLG(X_train, y_train, X_test, y_test)
# Out:
# Best: 0.882703 using {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.881515 (0.036814) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.881515 (0.036814) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.881518 (0.036659) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.882703 (0.035342) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.882703 (0.035342) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.882406 (0.035667) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.872571 (0.037449) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.872571 (0.037449) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.871372 (0.037162) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.736808 (0.030048) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.736808 (0.030048) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# ...

# %%
clf_lg_Tfidf_opt = LogisticRegression(C= 100,solver = 'liblinear' )
clf_lg_Tfidf_opt.fit(X_train, y_train)
y_pred_lg_Tfidf_opt = clf_lg_Tfidf_opt.predict(X_test)
clf_lg_Tfidf_score_opt = clf_lg_Tfidf_opt.score(X_test, y_test)
print(clf_lg_Tfidf_score_opt)
binarizer = MultiLabelBinarizer()
binarizer.fit(y_test)
f1_score_Tfidf_opt_lg =f1_score(binarizer.transform(y_test), binarizer.transform(y_pred_lg_Tfidf_opt),  average='macro') 
accuracy_score_Tfidf_opt_lg = accuracy_score(binarizer.transform(y_test), binarizer.transform(y_pred_lg_Tfidf_opt))
print("f1 score: %s accuracy_score: %s" % (f1_score_Tfidf_opt_lg, accuracy_score_Tfidf_opt_lg))
# Out:
# 0.9081419624217119
# f1 score: 0.9154741961003303 accuracy_score: 0.9081419624217119

# %% [markdown]
# #### Random Forest

# %%
#testingForGridsRF(X_train, y_train, X_test, y_test)

# %%
clf_rfc_Tfidf_opt = RandomForestClassifier(n_estimators= 2000, min_samples_split= 2, min_samples_leaf= 2, 
                                           max_features= 'auto', max_depth= 110, bootstrap= False)

clf_rfc_Tfidf_opt.fit(X_train, y_train)
y_pred_rfc_Tfidf_opt = clf_rfc_Tfidf_opt.predict(X_test)
clf_rfc_Tfidf_score_opt = clf_rfc_Tfidf_opt.score(X_test, y_test)
print(clf_rfc_Tfidf_score_opt)
binarizer = MultiLabelBinarizer()
binarizer.fit(y_test)
f1_score_Tfidf_opt_rfc =f1_score(binarizer.transform(y_test), binarizer.transform(y_pred_rfc_Tfidf_opt),  average='macro') 
accuracy_score_Tfidf_opt_rfc = accuracy_score(binarizer.transform(y_test), binarizer.transform(y_pred_rfc_Tfidf_opt))
print("f1 score: %s accuracy_score: %s" % (f1_score_Tfidf_opt_rfc, accuracy_score_Tfidf_opt_rfc))
# Out:
# 0.8935281837160751
# f1 score: 0.9022253756915473 accuracy_score: 0.8935281837160751

# %%
method_tuned = ['Support Vector Machine','logistic regression','random forest']
y_pred = [y_pred_svm_Tfidf_opt, y_pred_lg_Tfidf_opt,y_pred_rfc_Tfidf_opt]
f1_sc_Tfidf_opt = [f1_score_Tfidf_opt_svm,f1_score_Tfidf_opt_lg,f1_score_Tfidf_opt_rfc]
acc_sc_Tfidf_opt = [accuracy_score_Tfidf_opt_svm,accuracy_score_Tfidf_opt_lg,accuracy_score_Tfidf_opt_rfc]

plt.plot(method_tuned,f1_sc_Tfidf_opt, '-*', label='f1_score' )
plt.plot(method_tuned,acc_sc_Tfidf_opt, '-*', label='accuracy' )
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Observation
# <div class="alert alert-warning">
# After optimising the parameters, we have a global improvement of the different score metrics. While the three approach are comparables, the SVM is slightly better than the other.
# </div>

# %% [markdown]
# ### Results of classical approaches

# %%
fig = plt.figure(figsize=(20,6))
method_all_tuned = ['Support Vector Machine Tfidf','logistic regression Tfidf','random forest Tfidf', 'Support Vector Machine CountVec',
                'logistic regression CountVec','random forest CountVec','stoc gradient descent CountVec']
y_pred = [y_pred_svm_Tfidf_opt, y_pred_lg_Tfidf_opt,y_pred_rfc_Tfidf_opt, y_pred_svm_opt, y_pred_lg_opt, y_pred_sgd_opt]
f1_sc_all_opt = [f1_score_Tfidf_opt_svm,f1_score_Tfidf_opt_lg,f1_score_Tfidf_opt_rfc, f1_score_opt_svm, f1_score_opt_lg, 
                   f1_score_opt_rfc, f1_score_opt_sgd]
acc_sc_all_opt = [accuracy_score_Tfidf_opt_svm,accuracy_score_Tfidf_opt_lg,accuracy_score_Tfidf_opt_rfc, 
                    accuracy_score_opt_svm,accuracy_score_opt_lg,accuracy_score_opt_rfc,accuracy_score_opt_sgd]

plt.plot(method_all_tuned,f1_sc_all_opt, '-*', label='f1_score' )
plt.plot(method_all_tuned,acc_sc_all_opt, '-*', label='accuracy' )
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Results
# <div class="alert alert-warning">
# While in overall most of the algorithms showed good results. Using the features from Tf-Idf was been better than using countVector and The SVM with Tf-Idf feature provides the best scores of more than 90% in accuract and F1 score.
# </div>

# %% [markdown]
# # Neural Networ approach
# >

# %% [markdown]
# ##First approach using Tf-Idf

# %% [markdown]
# ### <u> MODEL: MLP from (keras) </u>
# We have also tested mlp from keras and this type of machine learning method is an artificial neural networks and uses a multilayer-perceptron model, one of the simplest types among such networks. An artificial neuron, also called a perceptron, is a unit or analytical function that can receive any number of numeric inputs, and provides one numeric output.
#
# Our mlp model consists of an input layer, a hidden layer and an output layer. The input layer is a layer without weights with as many neurons as there are elements in the text vectors. In the hidden layer, we have experimented with different numbers of neurons, through testing(for.example 10, 100, 150, 300) we concluded that 250 neurons give good results. The output layer consists of one neuron, for truthful/deceptive. We only use one hidden layer because we do not have enough data to train a more complicated model.
#
# In the hidden layer, the neurons have ReLU as activation function and the output layer has sigmoid as activation function. ReLU is recognized as both effective and useful for learning in neural networks. We use binary crossentropy as the loss function and the loss function must be derivable with regard to the activation functions in the network to enable learning. As an optimization function, we used a modern and recognized version of backpropagation(algorithm for optimizing artificial neural networks), called Adamax.
#
# TidfVectorizer gives us the ability to look at occurrences of sequences of two or more words. This can be interesting because certain word pairs or longer sequences can describe something completely unique and differ from cases where the words are used separately over an entire reviews. Each such sequence is considered a unique word and longer sequences can lead to large numbers of vocabulary and thus the length of the vectors. Then vectors for our dataset have become several thousands elements long and this could lead to a long driving time for training the model if we had good enough data. For our learning purpose, we assumed that we have enough data and used another class from Scikit-Learn's feature extraction module called, SelectKBest. It allows us to build a new vocabulary, of a given size, which consists of the words that best represent. This is done through the class "fit" method and then we minimize the vectors through the class' "transform" method. This could have helped to reduce run time, without having a major impact on the model's accuracy, again if we would have a large data. We point out this for quality reasons and assuming the model would have been distributed in the cloud and serve for a large amount of data
#
# To implement the model, we have used the TythorFlow python library:

# %%
import sys
d2 = []
for i in range(len(d_copy[classifications])):
    if (d_copy[classifications][i] == "deceptive"):
        x = 0
        d2.append([x, d_copy[reviews][i]])
    elif(d_copy[classifications][i] == "truthful"):
        x = 1
        d2.append([x, d_copy[reviews][i]])

# %%
df2 = pd.DataFrame(d2, columns=['label','review'])

# %%
# Split lists into training and validation data:
train_texts, val_texts, train_labels, val_labels = train_test_split(df2["review"], df2["label"], test_size=0.3,
                                                                    random_state=42)
# Convert label-lists to numpy for compatibility with keras:
train_labels, val_labels = np.array(train_labels), np.array(val_labels)
print(len(train_texts))
print(train_labels)
print(len(val_texts))
print(len(val_labels))
# Out:
# 1117
# [1 1 1 ... 0 1 0]
# 479
# 479

# %%
vectorizer = TfidfVectorizer(ngram_range = (1, 3), dtype = np.float32,analyzer = "word", min_df = 2)

# Learn vocabulary training texts.
x_train = vectorizer.fit_transform(train_texts)

# Vectorize validation texts.
x_val = vectorizer.transform(val_texts)

x_train.shape
# Out:
# (1117, 33542)

# %%
# Select top 'k' of the vectorized features.
selector = SelectKBest(f_classif, k="all")

# Transform x_train and x_val with top 'k' features and convert to numpy:
x_train = selector.fit_transform(x_train, train_labels).astype("float32").toarray()
x_val = selector.transform(x_val).astype("float32").toarray()

# %%
# Create a multilayer-perceptron model:

model = models.Sequential()

# Input layer and first hidden layer:
model.add(Dense(units=250, input_shape=x_train.shape[1:], activation="relu"))
# Dropout layer to help prevent overfitting:
model.add(Dropout(rate=0.2))
# Output layer:
model.add(Dense(units=1, activation="sigmoid")) #softmax

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_17 (Dense)             (None, 250)               8385750
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 250)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 251
# ...
# Total params: 8,386,001
# Trainable params: 8,386,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# This is used to make the model more likely to guess that a sample belongs to an underrepresented label.
#class_weight = class_weight.compute_class_weight("balanced", np.unique(train_labels), train_labels)

# Set final hyperparamaters:
learning_rate=1e-3
epochs=6
batch_size=128
loss = "binary_crossentropy"
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)

model.compile(optimizer=optimizer, loss=loss, metrics=["acc"])

# Create callback for early stopping on validation loss. If the loss does
# not decrease in two consecutive tries, stop training.
callbacks = [tf.keras.callbacks.EarlyStopping(
      monitor="val_loss", patience=2)]

# Train and validate model.
history = model.fit(
        x_train,
        train_labels,
        epochs=epochs,
        callbacks=callbacks,
        validation_data=(x_val, val_labels),
        verbose=2,  # Logs once per epoch.
        #class_weight=class_weight,
        batch_size=batch_size)

# Print results.
history = history.history
accuracy_NN_Tfidf = history['val_acc'][-1]
print("Validation accuracy: {acc}, loss: {loss}".format(acc=history["val_acc"][-1], loss=history["val_loss"][-1]))
# Out:
# Epoch 1/6
# 9/9 - 0s - loss: 0.6789 - acc: 0.6437 - val_loss: 0.6454 - val_acc: 0.8706
# Epoch 2/6
# 9/9 - 0s - loss: 0.5454 - acc: 0.9919 - val_loss: 0.5700 - val_acc: 0.8852
# Epoch 3/6
# 9/9 - 0s - loss: 0.3928 - acc: 0.9955 - val_loss: 0.5002 - val_acc: 0.8810
# Epoch 4/6
# 9/9 - 0s - loss: 0.2613 - acc: 0.9991 - val_loss: 0.4365 - val_acc: 0.8935
# Epoch 5/6
# 9/9 - 0s - loss: 0.1668 - acc: 1.0000 - val_loss: 0.3899 - val_acc: 0.8914
# Epoch 6/6
# 9/9 - 0s - loss: 0.1065 - acc: 1.0000 - val_loss: 0.3571 - val_acc: 0.8914
# Validation accuracy: 0.8914405107498169, loss: 0.35711562633514404

# %%
fig = plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.grid()

plt.subplot(1,2,2)
plt.plot(history['acc'])
plt.plot(history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# ### Overfitting

# %% [markdown]
# It is difficult to see that the model is exposed to an effect called "overfitting" due to lack of data, and the figure does not give a stable result every time it runs. By "overfitting" we mean that the model is adapting to the training data so much that it is getting worse on recognizing other data. The graph to the left shows the result of the loss function over training epochs.
#
# On the right side the accuracy from the first six epochs is shown. Here, the trained and validated data diverge. Even the results show a clear accuracy of about 87 percent, it is uncertain whether the model will be able to maintain the same accuracy for the remaining. And this is as a control check to assess whether the figure on the left side is correct or not. We do this to see if the model actually improves.
#
# We have also checked the classification report, it seems very unstable the way the model trained for some reason.

# %%
from sklearn.metrics import multilabel_confusion_matrix
import seaborn as sns

y_pred = model.predict(x_val)
y_pred = [[1.0 if n > 0.1 else 0.0 for n in row] for row in y_pred]

print(classification_report(val_labels, y_pred, target_names=None))
conf = multilabel_confusion_matrix(val_labels, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-2178f52f7510> in <module>
#       2 import seaborn as sns
#       3
# ----> 4 y_pred = model.predict(x_val)
#       5 y_pred = [[1.0 if n > 0.1 else 0.0 for n in row] for row in y_pred]
#       6
#
# NameError: name 'model' is not defined

# %%
for i, matrix in enumerate(conf):
    tick_labels = ['Other', df2["label"].unique()[i]]
    plt.figure()
    sns.heatmap(matrix, annot=True, fmt='d',
                xticklabels=tick_labels,
                yticklabels=tick_labels)
    plt.yticks(rotation=0)

# %% [markdown]
# ## Deep Learning using Word Embedding (GloVe)

# %% [markdown]
# Deep Learning is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called artificial neural networks.
#
# GloVe is an unsupervised learning algorithm for obtaining vector representations for words. Training is performed on aggregated global word-word co-occurrence statistics from a corpus, and the resulting representations showcase interesting linear substructures of the word vector space.
#
# In this part of the project, we have used different deeplearning methods to detect falsefull hotel reviews. The models has been using GloVe [11] Word Embedding. Following approach was adopted from ref[8].

# %%
# Make a copy of the dataframe fot the given task
df3 = df.copy()
df3=df3.drop(columns=['polarity', 'source' , 'hotel'],axis=1)
df3.classification.unique()
# Out:
# array(['deceptive', 'truthful'], dtype=object)

# %%
# Label encoder encodes classification for binary numbers (0,1) for truthfull and falsefull comments.

# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
# Encode labels in column 'classification'. 
df3['classification']= label_encoder.fit_transform(df3['classification']) 
df3['classification'].unique()
#df3 = df3.sample(frac=1.0)
df3.shape
# Out:
# (1600, 2)

# %%
def text_to_wordlist(text): 
    '''   
    Remove Special Characters
    '''
    text = re.sub(r'[^a-z\d ]', " ", text)
    text = re.sub(r'\d+', '_num_', text)    
    return(text)

# %%
# Split the given dataset for test and training datasets. Ans Tokonize the words
X_LSTM = df3.review
y_LSTM = df3.classification
X_LSTM = X_LSTM.map(lambda a: text_to_wordlist(a))
train_LSTM, test_LSTM, y_train, y_test = train_test_split(X_LSTM,y_LSTM,stratify=y_LSTM,random_state=42, test_size=0.3, shuffle=True)
tokenizer = Tokenizer(num_words=None,lower=True,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',split=' ',char_level=False)
tokenizer.fit_on_texts(X_LSTM)
x_train = tokenizer.texts_to_sequences(train_LSTM)
x_test = tokenizer.texts_to_sequences(test_LSTM)
word_index = tokenizer.word_index
len(word_index)
# Out:
# 10153

# %%
# Get the general information about the reviews
X_LSTM = tokenizer.texts_to_sequences(X_LSTM)
vocab_size = len(word_index)
longest = max(len(seq) for seq in X_LSTM)
average = np.mean([len(seq) for seq in X_LSTM])
stdev = np.std([len(seq) for seq in X_LSTM])
max_len = int(average + stdev * 3)
print('Vocab size: {}'.format(vocab_size))
print("Longest comment size: {}".format(longest))
print("Average comment size: {}".format(average))
print("Stdev of comment size: {}".format(stdev))
print('Max comment size: {}'.format(max_len))
# Out:
# Vocab size: 10153
# Longest comment size: 782
# Average comment size: 146.425
# Stdev of comment size: 85.91541261613075
# Max comment size: 404

# %%
# Padding of the words to get same size of word vectors for deeplearning.
processed_post_x_train = pad_sequences(x_train, maxlen=max_len, padding='post', truncating='post')
processed_post_x_test = pad_sequences(x_test, maxlen=max_len, padding='post', truncating='post')
processed_x_train = pad_sequences(x_train, maxlen=max_len)
processed_x_test = pad_sequences(x_test, maxlen=max_len)
print('x_train shape:', processed_x_train.shape)
print('x_test shape:', processed_x_test.shape)
# Out:
# x_train shape: (1120, 404)
# x_test shape: (480, 404)

# %%
# Download the Glove.6B file from the internet and unzip.
#!wget "http://nlp.stanford.edu/data/glove.6B.zip" 
#!unzip glove.6B.zip
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
embedding_dim = 100

# %%
# Create embeding dictianary form the Glove text data. The Glove data has 100 dimensions and 400000 words
embeddings_dict = {}
with open("glove.6B.100d.txt", 'r', encoding="utf-8") as f:
    for line in f: 
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], "float32")
        embeddings_dict[word] = coefs
f.close
print('Found %s word vectors.' % len(embeddings_dict))
# Out:
# Found 400000 word vectors.

# %%
# Create embedding matric by using embedding dictionary create above. k = 0
k = 0
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_dict.get(word)
    if embedding_vector is not None:
        # Words not found in embedding index will be all-zeros.
        k += 1
        embedding_matrix[i] = embedding_vector
embedding_matrix.shape
# Out:
# (10154, 100)

# %% [markdown]
# #### MODEL 1.

# %%
# Initiate the model 

def model1(embedding_matrix):
  '''
  MODEL 1. (LSTM 2 layer + CNN + GloVe )
    - Layer 1 is Embedding Layer (Coming from GLove)
    - Layer 2 is LSTM (60 Neurons)
    - Layer 3 is LSTM (30 Neurons) 
    - Layer 4 is 1D Convolution Layer
  '''
  model = Sequential()
  model.add(Embedding(vocab_size + 1, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=True))
  model.add(LSTM(60, return_sequences=True, name='lstm_layer1'))
  model.add(LSTM(30, return_sequences=True, name='lstm_layer2'))
  model.add(Conv1D(filters=128, kernel_size=3, padding='same', activation='relu'))
  model.add(MaxPooling1D(3))
  model.add(GlobalMaxPooling1D())
  model.add(BatchNormalization())
  model.add(Dense(64, activation='relu',kernel_regularizer=l2(0.17),bias_regularizer=l2(0.01)))
  model.add(Dropout(0.3))
  model.add(Dense(32, activation='sigmoid',kernel_regularizer=l2(0.19),bias_regularizer=l2(0.01)))
  model.add(Dropout(0.3))
  model.add(Dense(1, activation='sigmoid'))
  model.summary()
  return model

model = model1(embedding_matrix)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 404, 100)          1015400
# _________________________________________________________________
# lstm_layer1 (LSTM)           (None, 404, 60)           38640
# _________________________________________________________________
# lstm_layer2 (LSTM)           (None, 404, 30)           10920
# _________________________________________________________________
# conv1d (Conv1D)              (None, 404, 128)          11648
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 134, 128)          0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# ...

# %%
# Run the model
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
history = model.fit(processed_x_train,y_train,validation_data=(processed_x_test,y_test),epochs=20,batch_size=32,verbose=1)
# Out:
# Epoch 1/20
# 35/35 [==============================] - 7s 187ms/step - loss: 18.4537 - accuracy: 0.5634 - val_loss: 13.7897 - val_accuracy: 0.6542
# Epoch 2/20
# 35/35 [==============================] - 6s 168ms/step - loss: 10.5930 - accuracy: 0.6929 - val_loss: 7.9407 - val_accuracy: 0.5375
# Epoch 3/20
# 35/35 [==============================] - 6s 158ms/step - loss: 6.0446 - accuracy: 0.7616 - val_loss: 4.5991 - val_accuracy: 0.7229
# Epoch 4/20
# 35/35 [==============================] - 6s 162ms/step - loss: 3.4823 - accuracy: 0.8241 - val_loss: 2.7737 - val_accuracy: 0.7667
# Epoch 5/20
# 35/35 [==============================] - 5s 155ms/step - loss: 2.0687 - accuracy: 0.8732 - val_loss: 1.8162 - val_accuracy: 0.7063
# Epoch 6/20
# 35/35 [==============================] - 6s 158ms/step - loss: 1.3046 - accuracy: 0.9223 - val_loss: 1.1950 - val_accuracy: 0.8396
# Epoch 7/20
# ...

# %%
loss, accuracy_model1 = model.evaluate(processed_x_test,y_test)
def plotacc(history):
  # Plot training & validation accuracy values
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

  # Plot training & validation loss values
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'], loc='upper left')
  plt.show()

plotacc(history)
# Out:
# 15/15 [==============================] - 1s 46ms/step - loss: 0.6890 - accuracy: 0.8333

# %% [markdown]
# ##### Observation
# <div class="alert alert-warning">
# From the model above we have following observations.
#
# *   Accuracy for training set 98%.
# * Accuracy on the test set 82%.
# *   Loss value for train and test almost converged after 20 epochs.

# %% [markdown]
# #### Model 2.

# %%
# Initiate the model 
'''
MODEL 2. ( CNN + GloVe )
  - Layer 1 is Embedding Layer (Coming from GLove)
  - Layer 2 is 1D Convolution Layer
  - Layer 3 is LSTM (100 Neurons) 

'''
model_CNN = Sequential()
model_CNN.add(Embedding(vocab_size + 1, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=True))
model_CNN.add(Dropout(0.2))
model_CNN.add(Conv1D(64, 5, activation='relu',kernel_regularizer=l2(0.01),bias_regularizer=l2(0.01)))
model_CNN.add(MaxPooling1D(pool_size=4))
model_CNN.add(BatchNormalization())
model_CNN.add(LSTM(100,kernel_regularizer=l2(0.01),recurrent_regularizer=l2(0.01)))
model_CNN.add(Dense(1, activation='sigmoid',kernel_regularizer=l2(0.01),bias_regularizer=l2(0.01)))
model_CNN.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, 404, 100)          1015400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 404, 100)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 400, 64)           32064
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 100, 64)           0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 64)           256
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               66000
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 101
# ...

# %%
# Run the model
model_CNN.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history = model_CNN.fit(processed_x_train,y_train,validation_data=(processed_x_test,y_test),epochs=30,batch_size=32,verbose=1)
lossCNN , accuracyCNN = model_CNN.evaluate(processed_x_test,y_test)
# Out:
# Epoch 1/30
# 35/35 [==============================] - 3s 84ms/step - loss: 2.8261 - accuracy: 0.5777 - val_loss: 2.2383 - val_accuracy: 0.5083
# Epoch 2/30
# 35/35 [==============================] - 3s 74ms/step - loss: 1.7139 - accuracy: 0.7223 - val_loss: 1.5290 - val_accuracy: 0.6250
# Epoch 3/30
# 35/35 [==============================] - 3s 74ms/step - loss: 1.2088 - accuracy: 0.7920 - val_loss: 1.3399 - val_accuracy: 0.5813
# Epoch 4/30
# 35/35 [==============================] - 3s 74ms/step - loss: 0.9125 - accuracy: 0.8625 - val_loss: 1.0364 - val_accuracy: 0.7521
# Epoch 5/30
# 35/35 [==============================] - 3s 78ms/step - loss: 0.7059 - accuracy: 0.9277 - val_loss: 0.9873 - val_accuracy: 0.7146
# Epoch 6/30
# 35/35 [==============================] - 3s 78ms/step - loss: 0.6140 - accuracy: 0.9339 - val_loss: 0.9812 - val_accuracy: 0.7396
# Epoch 7/30
# ...

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observation
# <div class="alert alert-warning">
# From the model above we have following observations.
#
# *   Accuracy for training set 99%.
# * Accuracy on the test set 87%.
# *   Loss value for train and test datasets are different, thich points to overfitting. And the model seems to be not stable.

# %% [markdown]
# #### MODEL 3.

# %%
# Initiate the model 
def model3(embedding_matrix):
  '''
  MODEL 3. (LSTM 2 layer )
    - Layer 1 is Embedding Layer (Coming from GLove)
    - Layer 2 is LSTM (60 Neurons)
    - Layer 3 is LSTM (30 Neurons) 
  '''
  model_lstm = Sequential()

  model_lstm.add(Embedding(vocab_size + 1, embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=True))

  input_shape = embedding_matrix[0].shape
  model_lstm.add(LSTM(60, return_sequences=True, name='lstm_layer1'))
  model_lstm.add(LSTM(30, return_sequences=True, name='lstm_layer2'))
  model_lstm.add(BatchNormalization())
  model_lstm.add(Flatten())
  model_lstm.add(Dense(64, activation='relu',kernel_regularizer=l2(0.17),bias_regularizer=l2(0.01)))
  model_lstm.add(Dropout(0.3))
  model_lstm.add(Dense(32, activation='sigmoid',kernel_regularizer=l2(0.19),bias_regularizer=l2(0.01)))
  model_lstm.add(Dropout(0.3))
  model_lstm.add(Dense(20, activation='relu', input_shape=input_shape))
  model_lstm.add(Dropout(0.3))
  model_lstm.add(Dense(1, activation='sigmoid'))
  model_lstm.summary()
  return model_lstm
model_lstm = model3(embedding_matrix)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 404, 100)          1015400
# _________________________________________________________________
# lstm_layer1 (LSTM)           (None, 404, 60)           38640
# _________________________________________________________________
# lstm_layer2 (LSTM)           (None, 404, 30)           10920
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 404, 30)           120
# _________________________________________________________________
# flatten (Flatten)            (None, 12120)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                775744
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# ...

# %%
# Run the model
model_lstm.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
hist = model_lstm.fit(processed_x_train,y_train,validation_data=(processed_x_test,y_test),epochs=15,batch_size=32,verbose=1)
loss_LSTM, accuracy_LSTM =  model_lstm.evaluate(processed_x_test,y_test)
# Out:
# Epoch 1/15
# 35/35 [==============================] - 6s 171ms/step - loss: 11.7903 - accuracy: 0.5063 - val_loss: 6.2772 - val_accuracy: 0.5000
# Epoch 2/15
# 35/35 [==============================] - 6s 162ms/step - loss: 5.0589 - accuracy: 0.5420 - val_loss: 4.0715 - val_accuracy: 0.6250
# Epoch 3/15
# 35/35 [==============================] - 6s 164ms/step - loss: 3.3591 - accuracy: 0.6554 - val_loss: 2.7594 - val_accuracy: 0.7521
# Epoch 4/15
# 35/35 [==============================] - 6s 158ms/step - loss: 2.2248 - accuracy: 0.7777 - val_loss: 1.9042 - val_accuracy: 0.7229
# Epoch 5/15
# 35/35 [==============================] - 6s 157ms/step - loss: 1.4771 - accuracy: 0.8562 - val_loss: 1.3925 - val_accuracy: 0.7458
# Epoch 6/15
# 35/35 [==============================] - 6s 165ms/step - loss: 1.0189 - accuracy: 0.8929 - val_loss: 1.1208 - val_accuracy: 0.7188
# Epoch 7/15
# ...

# %%
# Plot training & validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observation
# <div class="alert alert-warning">
# From the model above we have following observations.
#
# *   Accuracy for training set 99%.
# * Accuracy on the test set 80%.
# *   Loss value for train and test datasets are similar, though test loss is higher, which might mean it is underfitting the model.

# %% [markdown]
# #### Training our own word embedding with word2vec

# %%
num_features = max_len    #Dimensionality of the word vectors.
min_word_count = 1 #Minimum word count to include    
context = 5  #Maximum distance between the current and predicted word within a sentence.   
epochs = 10 #Number of iterations over the corpus
alg = 1 #Training algorithm: Skip-gram

reviews=[] #corpus
for text in clean_review:
  reviews.append(text.split())

word2vec_model = gensim.models.word2vec.Word2Vec(
                    sentences=reviews,
                    sg=alg,
                    size = num_features,
                    window=context,
                    min_count=min_word_count,
                    iter=epochs)

# %%
print(word2vec_model.wv.doesnt_match("man woman child kitchen".split()))
# Out:
# kitchen
# C:\Users\aanupam\AppData\Roaming\Python\Python37\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
print(word2vec_model.wv.most_similar("tv"))
# Out:
# [('television', 0.9400219321250916), ('screen', 0.9367252588272095), ('flat', 0.9336289763450623), ('lcd', 0.9244593381881714), ('plasma', 0.9242779016494751), ('tvs', 0.9159426689147949), ('inch', 0.9152448177337646), ('televisions', 0.9101243019104004), ('bose', 0.9068113565444946), ('bath', 0.9003380537033081)]

# %% [markdown]
# ##### Observation
# <div class="alert alert-warning">
# We can observe that the word embedding has found corolation between the words in the dataset

# %%
k = 0
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    if word in word2vec_model.wv.vocab:
        embedding_vector = word2vec_model.wv.vocab[word].index
    else:
        continue
    if embedding_vector is not None:
        k += 1
        embedding_matrix[i] = embedding_vector
embedding_matrix.shape
# Out:
# (10154, 100)

# %%
# MODEL 1. wordToVec
model1_wordToVec = model1(embedding_matrix)
model1_wordToVec.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
history = model1_wordToVec.fit(processed_x_train,y_train,validation_data=(processed_x_test,y_test),epochs=20,batch_size=32,verbose=0)
loss_wordToVec_model1, accuracy_wordToVec_model1 =  model1_wordToVec.evaluate(processed_x_test,y_test)
plotacc(history)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_3 (Embedding)      (None, 404, 100)          1015400
# _________________________________________________________________
# lstm_layer1 (LSTM)           (None, 404, 60)           38640
# _________________________________________________________________
# lstm_layer2 (LSTM)           (None, 404, 30)           10920
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 404, 128)          11648
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 134, 128)          0
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# ...

# %%
# MODEL 3. wordToCec (LSTM 2 layer)
model3_wordToVec_lstm = model3(embedding_matrix)
model3_wordToVec_lstm.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
hist = model3_wordToVec_lstm.fit(processed_x_train,y_train,validation_data=(processed_x_test,y_test),epochs=15,batch_size=32,verbose=0)
# loss_wordToVec__LSTM, accuracy_wordToVec__LSTM =  model3_wordToVec_lstm.evaluate(processed_x_test,y_test)
plotacc(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_4 (Embedding)      (None, 404, 100)          1015400
# _________________________________________________________________
# lstm_layer1 (LSTM)           (None, 404, 60)           38640
# _________________________________________________________________
# lstm_layer2 (LSTM)           (None, 404, 30)           10920
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 404, 30)           120
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12120)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                775744
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# ...

# %% [markdown]
# ### Conclusion on pre-trained vs our own word embedding
#
# The models did not perform equally as well as with pre-trained word embedding. We might improve our result by tuning the parameters, but since our training data is small we can conclude that for this dataset GloVe is superior

# %% [markdown]
# ## Final results

# %%
method_f = ['svm_Tfidf', 'NN_Tfidf','NN_model1','NN_model2','NN_model3','NN_model1_wordToVec']
acc_sc = [accuracy_score_Tfidf_opt_svm, accuracy_NN_Tfidf ,accuracy_model1,accuracyCNN,accuracy_LSTM ,accuracy_wordToVec_model1]

plt.plot(method_f,acc_sc, '-*', label='accuracy' )
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Judging by the accuracy and F1scores of the different methods in both classical approaches, and neural network, we find that the best method is was found to be SVM with Fi-tdf features.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This project gives good insights into the field of Natural Language Processing (NLP) and how machine learning is used to deal with text data.
#
# Our tasks consist of implementing different supervised machine learning approaches to analyze word data (reviews) and to classify them into truthful and falsful and to compare and evaluate these algorithms.
#
# To do so, we dived on literatures on the different methods to transform word data to meaningful features with ngram and word embedding and on the different machine leaning approaches and their implementation.
#
# Classical approaches as (svm, decision tree, random forest, logistic regression, naive Bayes, K neighbors and stochastic gradient descent for sklearn library) were used using features from countvectoriser and Ft-idf after cleaning the data using (removing stop words and punctuations, stemming, ..., (depending on the method used)).
#
# Neural network method were used also with both Tfidf as first approach and word embedding gloves (3models) and wordtoVec (1model) as a second approach.
#
# So, we generated multiples approaches (up to 17). These approaches were then compared and the best method was found to be SVM with Fi-tdf features.
#
# While, we think that our methodology and workflows have good results it would be best to try it with a larger dataset, as the dataset used is quite limited compared to the number of features.
#
# Human performance is low in terms of detecting deceptive information [9] with accuracy not higher than chance. So, it is almost impossible for a human to come up with  similar results that we got using machine learning techniques. Thus, the importance of such work to automatically filter reviews and fake news and information in the future.

# %% [markdown]
# ## <h1><center> References</center></h1>

# %% [markdown]
# [1] https://monkeylearn.com/blog/what-is-tf-idf/
#
# [2] https://www.analyticsvidhya.com/blog/2017/06/word-embeddings-count-word2veec/
#
# [3] https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
#
#
#
# [5]  https://keras.io/api/losses/https://keras.io/api/losses/
#
# [6] https://developers.google.com/machine-learning/guides/text-classification/step-4https://developers.google.com/machine-learning/guides/text-classification/step-4
#
# [7] https://towardsdatascience.com/how-to-make-sgd-classifier-perform-as-well-as-logistic-regression-using-parfit-cc10bca2d3c4
#
# [8] https://github.com/ashishsalunkhe/DeepSpamReview-Detection-of-Fake-Reviews-on-Online-Review-Platforms-using-DeepLearning-Architectures
#
# [9] M. Ott, Y. Choi, C. Cardie, and J.T. Hancock. 2011. Finding Deceptive
# Opinion Spam by Any Stretch of the Imagination. In Proceedings of the 49th
# Annual Meeting of the Association for Computational Linguistics: Human Language
# Technologies.
#
# [10] M. Ott, C. Cardie, and J.T. Hancock. 2013. Negative Deceptive Opinion Spam.
# In Proceedings of the 2013 Conference of the North American Chapter of the
# Association for Computational Linguistics: Human Language Technologies.
#
# [11] https://analyticsindiamag.com/7-types-classification-algorithms/
